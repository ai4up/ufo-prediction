# %%
# standard libs
import os
import sys
import logging

# project lib
PROJECT_SRC_PATH = os.path.join(os.path.abspath(''), '..', 'src')
sys.path.append(PROJECT_SRC_PATH)

import utils
import dataset
import visualizations
import energy_modeling
from prediction_age import AgePredictor, AgeClassifier, AgeClassifierComparison
from preprocessing import *

# external libs
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import geopandas as gpd
from shapely import wkt

from xgboost import XGBRegressor, XGBClassifier

# %%
logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s', level=logging.INFO)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Data

# %%
df_fr = dataset.load('france', geo=False)
df_fr_sample = utils.sample_cities(df_fr, 0.1)

# %%
df_nl = dataset.load('netherlands', geo=False)
df_nl_sample = utils.sample_cities(df_nl, 0.1)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# #### Extract heating demand from TABULA_parameters_harmonized.csv and format csv

# %%
# tabula_params = tabula_params[tabula_params['country'].isin(['Netherlands', 'Spain', 'France'])]

def set_label(df):
    bins = sorted(np.unique(df[['age_min', 'age_max']].values))
    df['age_bin'] = utils.generate_labels(bins)
    return df

tabula_params = tabula_params.groupby(['country', 'residential_type']).apply(set_label)
# Out:
# [0, 1945, 1946, 1971, 1991, 2006, 2012, 2051]
#     age_min  age_max
# 37        0     1945
# 38     1946     1971
# 39     1971     1991
# 40     1991     2006
# 41     2006     2012
# 42     2012     2051
# [0, 1945, 1946, 1971, 1991, 2006, 2012, 2051]
#     age_min  age_max
# 43        0     1945
# 44     1946     1971
# 45     1971     1991
# 46     1991     2006
# 47     2006     2012
# 48     2012     2051
# [0, 1945, 1946, 1971, 1991, 2006, 2012, 2051]
#     age_min  age_max
# 49        0     1945
# 50     1946     1971
# 51     1971     1991
# 52     1991     2006
# 53     2006     2012
# 54     2012     2051
# [0, 1918, 1919, 1930, 1960, 1999, 2009, 2051]
#     age_min  age_max
# 59        0     1918
# 60     1919     1930
# 61     1930     1960
# 62     1960     1999
# 63     1999     2009
# 64     2009     2051
# [0, 1918, 1919, 1930, 1960, 1999, 2009, 2051]
#     age_min  age_max
# 65        0     1918
# 66     1919     1930
# 67     1930     1960
# 68     1960     1999
# 69     1999     2009
# 70     2009     2051
# [0, 1918, 1919, 1930, 1960, 1999, 2009, 2051]
#     age_min  age_max
# 71        0     1918
# 72     1919     1930
# 73     1960     1999
# 74     1999     2009
# 75     2009     2051
# [0, 1980, 1981, 2007, 2014, 2051]
#     age_min  age_max
# 76        0     1980
# 77     1981     2007
# 78     2007     2014
# 79     2014     2051
# [0, 1980, 1981, 2007, 2014, 2051]
#     age_min  age_max
# 80        0     1980
# 81     1981     2007
# 82     2007     2014
# 83     2014     2051
# [0, 1980, 1981, 2007, 2014, 2051]
#     age_min  age_max
# 84        0     1980
# 85     1981     2007
# 86     2007     2014
# 87     2014     2051
# [0, 1920, 1921, 1946, 1961, 1981, 1995, 2011]
#     age_min  age_max
# 88        0     1920
# 89     1921     1946
# 90     1946     1961
# 91     1961     1981
# 92     1981     1995
# 93     1995     2011
# [0, 1920, 1921, 1946, 1961, 1981, 1995, 2011, 2051]
#      age_min  age_max
# 94         0     1920
# 95      1921     1946
# 96      1946     1961
# 97      1961     1981
# 98      1981     1995
# 99      1995     2011
# 100     2011     2051
# [0, 1920, 1921, 1946, 1961, 1981, 1995, 2011, 2051]
#      age_min  age_max
# 101        0     1920
# 102     1921     1946
# 103     1946     1961
# 104     1961     1981
# 105     1981     1995
# 106     1995     2011
# 107     2011     2051
# [0, 1920, 1921, 1946, 1961, 1981, 1995, 2011, 2051]
#      age_min  age_max
# 108        0     1920
# 109     1921     1946
# 110     1946     1961
# 111     1961     1981
# 112     1981     1995
# 113     1995     2011
# 114     2011     2051
# [0, 1850, 1851, 1931, 1951, 1961, 1973, 1979, 1999, 2007, 2011, 2051]
#      age_min  age_max
# 157        0     1850
# 158     1851     1931
# 159     1931     1951
# 160     1951     1961
# 161     1961     1973
# 162     1973     1979
# 163     1979     1999
# 164     1999     2007
# 165     2007     2011
# 166     2011     2051
# [0, 1850, 1851, 1931, 1951, 1961, 1973, 1979, 1999, 2007, 2011, 2051]
#      age_min  age_max
# 167        0     1850
# 168     1851     1931
# 169     1931     1951
# 170     1951     1961
# 171     1961     1973
# 172     1973     1979
# 173     1979     1999
# 174     1999     2007
# 175     2007     2011
# 176     2011     2051
# [0, 1850, 1851, 1931, 1951, 1961, 1973, 1979, 1999, 2007, 2011, 2051]
#      age_min  age_max
# 177        0     1850
# 178     1851     1931
# 179     1931     1951
# 180     1951     1961
# 181     1961     1973
# 182     1973     1979
# 183     1979     1999
# 184     1999     2007
# 185     2007     2011
# 186     2011     2051
# [0, 1980, 1981, 2001, 2011, 2051]
#      age_min  age_max
# 251        0     1980
# 252     1981     2001
# 253     2001     2011
# 254     2011     2051
# [0, 1980, 1981, 2001, 2011, 2051]
#      age_min  age_max
# 255        0     1980
# 256     1981     2001
# 257     2001     2011
# 258     2011     2051
# [1945, 1980, 1990, 2006, 2051]
#      age_min  age_max
# 259     1945     1980
# 260     1980     1990
# 261     2006     2051
# [1950, 1967, 1978, 1983, 1994, 2005, 2011, 2051]
#      age_min  age_max
# 272     1950     1967
# 273     1978     1983
# 274     1983     1994
# 275     1994     2005
# 276     2005     2011
# 277     2011     2051
# [0, 1955, 1956, 1971, 1981, 1991, 2001, 2011, 2051]
#      age_min  age_max
# 354        0     1955
# 355     1956     1971
# 356     1971     1981
# 357     1981     1991
# 358     1991     2001
# 359     2001     2011
# 360     2011     2051
# [0, 1955, 1956, 1971, 1981, 1991, 2001, 2011, 2051]
#      age_min  age_max
# 361        0     1955
# 362     1956     1971
# 363     1971     1981
# 364     1981     1991
# 365     1991     2001
# 366     2001     2011
# 367     2011     2051
# [0, 1955, 1956, 1971, 1981, 1991, 2001, 2011, 2051]
#      age_min  age_max
# 368        0     1955
# 369     1956     1971
# 370     1971     1981
# 371     1981     1991
# 372     1991     2001
# 373     2001     2011
# 374     2011     2051
# [0, 1945, 1946, 1971, 1981, 2002, 2009, 2051]
#      age_min  age_max
# 442        0     1945
# 443     1946     1971
# 444     1971     1981
# 445     1981     2002
# 446     2002     2009
# 447     2009     2051
# [0, 1945, 1946, 1971, 1981, 2002, 2009, 2051]
#      age_min  age_max
# 448        0     1945
# 449     1946     1971
# 450     1971     1981
# 451     1981     2002
# 452     2002     2009
# 453     2009     2051
# [0, 1945, 1946, 1971, 1981, 2002, 2009, 2051]
#      age_min  age_max
# 454        0     1945
# 455     1946     1971
# 456     1971     1981
# 457     1981     2002
# 458     2002     2009
# 459     2009     2051
# [0, 1945, 1946, 1971, 1981, 2002, 2009, 2051]
#      age_min  age_max
# 460        0     1945
# 461     1946     1971
# 462     1971     1981
# 463     1981     2002
# 464     2002     2009
# 465     2009     2051
# [0, 1960, 1961, 1976, 1986, 1996, 2006]
#      age_min  age_max
# 432        0     1960
# 433     1961     1976
# 434     1976     1986
# 435     1986     1996
# 436     1996     2006
# [0, 1960, 1961, 1976, 1986, 1996, 2006]
#      age_min  age_max
# 437        0     1960
# 438     1961     1976
# 439     1976     1986
# 440     1986     1996
# 441     1996     2006

# %%
def set_label(df):
    bins = sorted(np.unique(df[['age_min', 'age_max']].values))
    df['age_bin'] = utils.generate_labels(bins)
    return df

# load data
tabula_params_path = os.path.join('..', 'metadata', 'TABULA_parameters_harmonized.csv')
tabula_params = pd.read_csv(tabula_params_path)

tabula_params.rename(columns={'Country': 'country', 'BuildingType': 'residential_type', 'Age': 'age_bin', 'q_h_nd': 'heating_demand'}, inplace=True)

# filter for relevant countries
tabula_params = tabula_params[tabula_params['country'].isin(['Netherlands', 'Spain', 'France'])]

# add columns for upper and lower bound of age bin
tabula_params['age_min'] = tabula_params['age_bin'].str[:4].astype(int)
tabula_params['age_max'] = tabula_params['age_bin'].str[-4:].astype(int)
mask_upper_bound = (tabula_params['age_min'] == tabula_params['age_max']) & (tabula_params['age_max'] > 1990)
mask_lower_bound = (tabula_params['age_min'] == tabula_params['age_max']) & (tabula_params['age_max'] < 1990)
tabula_params.loc[mask_upper_bound, 'age_max'] = 2050
tabula_params.loc[mask_lower_bound, 'age_min'] = 0
tabula_params.loc[mask_lower_bound, 'age_max'] = tabula_params['age_max'] - 1
tabula_params['age_max'] = tabula_params['age_max'] + 1

# harmonize bin labels with labels generated by classifier
tabula_params = tabula_params.groupby(['country', 'residential_type']).apply(set_label)

# save relevant TABULA data
tabula_heating_path = os.path.join('..', 'metadata', 'TABULA_heating_demand.csv')
tabula_heating = tabula_params[['country', 'residential_type', 'age_bin', 'age_min', 'age_max', 'heating_demand']]
tabula_heating.to_csv(tabula_heating_path, index=False)

# %% [markdown]
# #### Defining age bins

# %%
tabula_params = tabula_params[tabula_params['Country'].isin(['Netherlands', 'Spain', 'France'])]

# tabula_combined_bins = sorted(tabula_bins['Age'][~tabula_bins['Age'].str.contains('<')].str[:4].unique())

tabula_combined_bins = sorted(tabula_params['Age_Harmonized'].str[:4].unique())
print(tabula_combined_bins)
tabula_combined_bins = sorted(tabula_params['Age'].str[:4].unique())
print(tabula_combined_bins)
tabula_combined_bins = sorted(tabula_params[tabula_params['Country'] == 'Netherlands']['Age'].str[:4].unique())
print(tabula_combined_bins)

tabula_params[tabula_params['Country'] == 'Spain'][['Country', 'BuildingType', 'Age', 'Age_Harmonized', 'q_h_nd']][:30]

# %% [markdown]
# ## Experiments

# %%
regressor_fr = AgePredictor(
    model=XGBRegressor(),
    df=df_fr_sample,
    test_training_split=split_80_20,
    preprocessing_stages=[remove_buildings_pre_1900]
)

regressor_nl = AgePredictor(
    model=XGBRegressor(),
    df=df_nl_sample,
    test_training_split=split_80_20,
    preprocessing_stages=[remove_buildings_pre_1900]
)

regressor_fr.print_model_error()
regressor_nl.print_model_error()
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 16:44:12,779 | INFO : Dataset length: 4441
# 2022-06-24 16:44:12,785 | INFO : Dataset allocated memory: 4 MB
# 2022-06-24 16:44:12,789 | INFO : Dataset standard deviation: 62.68525292516289
# 2022-06-24 16:44:12,790 | INFO : Dataset mean age: 1936.0225174510244
# 2022-06-24 16:44:12,791 | INFO : Training dataset length: 3552
# 2022-06-24 16:44:12,792 | INFO : Test dataset length: 889
# 2022-06-24 16:44:12,806 | INFO : Test dataset standard deviation after preprocessing: 33.72756817834984
# 2022-06-24 16:44:12,807 | INFO : Test dataset mean age after preprocessing: 1963.8566978193146
# 2022-06-24 16:44:12,807 | INFO : Training dataset length after preprocessing: 2692
# 2022-06-24 16:44:12,808 | INFO : Test dataset length after preprocessing: 642
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 16:44:13,936 | INFO : Dataset length: 81652
# 2022-06-24 16:44:13,941 | INFO : Dataset allocated memory: 82 MB
# 2022-06-24 16:44:14,038 | INFO : Dataset standard deviation: 32.724917318050515
# 2022-06-24 16:44:14,047 | INFO : Dataset mean age: 1973.7581320726988
# 2022-06-24 16:44:14,049 | INFO : Training dataset length: 65321
# 2022-06-24 16:44:14,051 | INFO : Test dataset length: 16331
# 2022-06-24 16:44:14,269 | INFO : Test dataset standard deviation after preprocessing: 25.744186391433637
# 2022-06-24 16:44:14,270 | INFO : Test dataset mean age after preprocessing: 1976.0853331671133
# 2022-06-24 16:44:14,270 | INFO : Training dataset length after preprocessing: 64251
# 2022-06-24 16:44:14,271 | INFO : Test dataset length after preprocessing: 16043
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# MAE: 18.55 y
# RMSE: 25.70 y
# R2: 0.4186
# MAE: 11.92 y
# RMSE: 18.21 y
# R2: 0.4999

# %%
bins_fr = sorted(np.unique(tabula_params[tabula_params['country'] == 'France'][['age_min', 'age_max']].values))
bins_nl = sorted(np.unique(tabula_params[tabula_params['country'] == 'Netherlands'][['age_min', 'age_max']].values))

classifier_fr = AgeClassifier(
    model=XGBClassifier(),
    df=df_fr_sample,
    test_training_split=split_80_20,
    mitigate_class_imbalance=True,
    bins=bins_fr,
    preprocessing_stages=[remove_buildings_pre_1900]
)

classifier_nl = AgeClassifier(
    model=XGBClassifier(),
    df=df_nl_sample,
    mitigate_class_imbalance=True,
    bins=bins_nl,
    test_training_split=split_80_20,
    preprocessing_stages=[remove_buildings_pre_1900]
)

classifier_fr.print_model_error()
classifier_nl.print_model_error()
# Out:
# [autoreload of prediction failed: Traceback (most recent call last):
#   File "/usr/local/Caskroom/miniconda/base/envs/uf-ml/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 257, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/Caskroom/miniconda/base/envs/uf-ml/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 480, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/Caskroom/miniconda/base/envs/uf-ml/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/usr/local/Caskroom/miniconda/base/envs/uf-ml/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 329, in update_class
#     if update_generic(old_obj, new_obj):
#   File "/usr/local/Caskroom/miniconda/base/envs/uf-ml/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 377, in update_generic
#     update(a, b)
#   File "/usr/local/Caskroom/miniconda/base/envs/uf-ml/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 289, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: classification_report() requires a code object with 1 free vars, not 0
# ]
# 2022-06-24 16:45:53,334 | INFO : Generated bins: [0, 1915, 1949, 1968, 1975, 1982, 1990, 2000, 2006, 2013, 2051]
# 2022-06-24 16:45:53,335 | INFO : Generated bins with the following labels: ['<1915', '1915-1948', '1949-1967', '1968-1974', '1975-1981', '1982-1989', '1990-1999', '2000-2005', '2006-2012', '2013-2050']
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 16:45:53,372 | INFO : Dataset length: 4441
# 2022-06-24 16:45:53,378 | INFO : Dataset allocated memory: 4 MB
# 2022-06-24 16:45:53,383 | INFO : Training dataset length: 3552
# 2022-06-24 16:45:53,384 | INFO : Test dataset length: 889
# 2022-06-24 16:45:53,391 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 16:45:53,398 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 16:45:53,413 | INFO : Training dataset length after preprocessing: 2692
# 2022-06-24 16:45:53,414 | INFO : Test dataset length after preprocessing: 642
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# 2022-06-24 16:46:00,602 | INFO : Generated bins: [0, 1965, 1975, 1992, 2006, 2015, 2051]
# 2022-06-24 16:46:00,603 | INFO : Generated bins with the following labels: ['<1965', '1965-1974', '1975-1991', '1992-2005', '2006-2014', '2015-2050']
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 16:46:00,732 | INFO : Dataset length: 81652
# 2022-06-24 16:46:00,739 | INFO : Dataset allocated memory: 82 MB
# 2022-06-24 16:46:00,809 | INFO : Training dataset length: 65321
# 2022-06-24 16:46:00,810 | INFO : Test dataset length: 16331
# 2022-06-24 16:46:00,850 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 16:46:00,892 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 16:46:01,033 | INFO : Training dataset length after preprocessing: 64251
# 2022-06-24 16:46:01,034 | INFO : Test dataset length after preprocessing: 16043
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# Classification report:
#                precision    recall  f1-score  support
# <1915          0.527778  0.606383  0.564356       94
# 1915-1948      0.519481  0.444444  0.479042       90
# 1949-1967      0.474138  0.533981  0.502283      103
# 1968-1974      0.382979  0.400000  0.391304       45
# 1975-1981      0.589744  0.500000  0.541176       92
# 1982-1989      0.470588  0.588235  0.522876       68
# 1990-1999      0.440000  0.372881  0.403670       59
# 2000-2005      0.382353  0.351351  0.366197       37
# 2006-2012      0.352941  0.333333  0.342857       36
# 2013-2050      0.461538  0.333333  0.387097       18
# accuracy       0.481308  0.481308  0.481308        0
# macro avg      0.460154  0.446394  0.450086      642
# weighted avg   0.482573  0.481308  0.479015      642
# Cohen’s kappa: 0.4101
# Matthews correlation coefficient (MCC): 0.4107
# Classification report:
#                precision    recall  f1-score  support
# <1965          0.740095  0.846590  0.789769     4413
# 1965-1974      0.858111  0.789957  0.822625     3047
# 1975-1991      0.862018  0.765813  0.811073     3826
# 1992-2005      0.736958  0.722270  0.729540     2308
# 2006-2014      0.645402  0.667658  0.656341     1682
# 2015-2050      0.670469  0.689700  0.679949      767
# accuracy       0.772424  0.772424  0.772424        0
# macro avg      0.752176  0.746998  0.748216    16043
# weighted avg   0.777878  0.772424  0.773186    16043
# Cohen’s kappa: 0.7140
# Matthews correlation coefficient (MCC): 0.7151

# %%
bins_fr
# Out:
# [0, 1915, 1949, 1968, 1975, 1982, 1990, 2000, 2006, 2013, 2051]

# %%
bins_fr = sorted(np.unique(tabula_params[tabula_params['country'] == 'France'][['age_min', 'age_max']].values))
bins_nl = sorted(np.unique(tabula_params[tabula_params['country'] == 'Netherlands'][['age_min', 'age_max']].values))

comparison_config = {
    'France': {'df': df_fr_sample, 'bins': bins_fr},
    'Netherlands': {'df': df_nl_sample, 'bins': bins_nl},
}

# has to be aligned with TABULA bins for heating demand
grid_comparison_config = {
    '': {},
    'peter': {'bins': [1900, 1945, 1970, 1980, 1990, 2000, 2010]},
    '25': {'bins': [], 'bin_config': (1900, 2025, 25)},
    '10': {'bins': [], 'bin_config': (1900, 2025, 10)},
    '5': {'bins': [], 'bin_config': (1900, 2025, 5)},
}

comparison = AgeClassifierComparison(
    model=XGBClassifier(tree_method='hist'),
    df=None,
    cross_validation_split=cross_validation,
    preprocessing_stages=[remove_buildings_pre_1900],
    bin_config=None,
    mitigate_class_imbalance=True,
    include_baseline=False,
    comparison_config=comparison_config,
    grid_comparison_config=grid_comparison_config,
)
# Out:
# 2022-06-24 18:03:22,760 | INFO : Starting experiment France__seed_0...
# 2022-06-24 18:03:22,778 | INFO : Generated bins: [0, 1915, 1949, 1968, 1975, 1982, 1990, 2000, 2006, 2013, 2051]
# 2022-06-24 18:03:22,779 | INFO : Generated bins with the following labels: ['<1915', '1915-1948', '1949-1967', '1968-1974', '1975-1981', '1982-1989', '1990-1999', '2000-2005', '2006-2012', '2013-2050']
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:22,812 | INFO : Dataset length: 4441
# 2022-06-24 18:03:22,819 | INFO : Dataset allocated memory: 4 MB
# 2022-06-24 18:03:22,825 | INFO : Training dataset length: 2960
# 2022-06-24 18:03:22,825 | INFO : Test dataset length: 1481
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:22,860 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:22,889 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 18:03:22,900 | INFO : Training dataset length after preprocessing: 2246
# 2022-06-24 18:03:22,901 | INFO : Test dataset length after preprocessing: 1088
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# 2022-06-24 18:03:27,584 | INFO : Training dataset length: 2961
# 2022-06-24 18:03:27,586 | INFO : Test dataset length: 1480
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:27,624 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:27,663 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 18:03:27,678 | INFO : Training dataset length after preprocessing: 2205
# 2022-06-24 18:03:27,679 | INFO : Test dataset length after preprocessing: 1129
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# 2022-06-24 18:03:32,132 | INFO : Training dataset length: 2961
# 2022-06-24 18:03:32,132 | INFO : Test dataset length: 1480
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:32,174 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:32,213 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 18:03:32,230 | INFO : Training dataset length after preprocessing: 2217
# 2022-06-24 18:03:32,231 | INFO : Test dataset length after preprocessing: 1117
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# 2022-06-24 18:03:37,234 | INFO : Starting experiment Netherlands__seed_0...
# 2022-06-24 18:03:37,266 | INFO : Generated bins: [0, 1965, 1975, 1992, 2006, 2015, 2051]
# 2022-06-24 18:03:37,267 | INFO : Generated bins with the following labels: ['<1965', '1965-1974', '1975-1991', '1992-2005', '2006-2014', '2015-2050']
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:37,381 | INFO : Dataset length: 81652
# 2022-06-24 18:03:37,388 | INFO : Dataset allocated memory: 82 MB
# 2022-06-24 18:03:37,436 | INFO : Training dataset length: 54434
# 2022-06-24 18:03:37,437 | INFO : Test dataset length: 27218
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:37,512 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:37,591 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 18:03:37,719 | INFO : Training dataset length after preprocessing: 53544
# 2022-06-24 18:03:37,720 | INFO : Test dataset length after preprocessing: 26750
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# 2022-06-24 18:03:48,854 | INFO : Training dataset length: 54435
# 2022-06-24 18:03:48,855 | INFO : Test dataset length: 27217
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:48,924 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:03:48,996 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 18:03:49,123 | INFO : Training dataset length after preprocessing: 53517
# 2022-06-24 18:03:49,123 | INFO : Test dataset length after preprocessing: 26777
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# 2022-06-24 18:04:00,646 | INFO : Training dataset length: 54435
# 2022-06-24 18:04:00,648 | INFO : Test dataset length: 27217
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:04:00,718 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 18:04:00,785 | INFO : age attribute has been categorized (lowest age included: 0; highest age included: 2050).
# 2022-06-24 18:04:00,914 | INFO : Training dataset length after preprocessing: 53527
# 2022-06-24 18:04:00,914 | INFO : Test dataset length after preprocessing: 26767
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.

# %%
comparison.evaluate(include_energy_error=False)
# Out:
# Note that pos_label (set to 0) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 2) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 3) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 4) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 5) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 6) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 7) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 8) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 9) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 0) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 2) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 3) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 4) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
# Note that pos_label (set to 5) is ignored when average != 'binary' (got 'macro'). You may use labels=[pos_label] to specify a single positive class.
#                   name       MCC        F1  Recall_<1915  Recall_1915-1948  \
# 0       France__seed_0  0.411497  0.455026      0.588372           0.52439
# 1  Netherlands__seed_0  0.707859  0.743114           NaN               NaN
#
#    Recall_1949-1967  Recall_1968-1974  Recall_1975-1981  Recall_1982-1989  \
# 0          0.547573          0.246914           0.51417           0.49863
# 1               NaN               NaN               NaN               NaN
#
#    Recall_1990-1999  Recall_2000-2005  Recall_2006-2012  Recall_2013-2050  \
# 0          0.425868          0.427885          0.347594          0.361446
# 1               NaN               NaN               NaN               NaN
#
#    Recall_<1965  Recall_1965-1974  Recall_1975-1991  Recall_1992-2005  \
# 0           NaN               NaN               NaN               NaN
# 1      0.840732          0.779944          0.765113           0.72185
#
#    Recall_2006-2014  Recall_2015-2050
# 0               NaN               NaN
# 1           0.65476          0.679245

# %%
classifier_nl.aux_vars_test['country'] = 'Netherlands'
regressor_nl.aux_vars_test['country'] = 'Netherlands'
classifier_fr.aux_vars_test['country'] = 'France'
regressor_fr.aux_vars_test['country'] = 'France'

# %%
for predictor in [regressor_fr, classifier_fr, regressor_nl, classifier_nl]:
    aux_vars = pd.concat([predictor.aux_vars_test, predictor.X_test[['FootprintArea']]], axis=1, join="inner")
    labels = getattr(predictor, 'labels', None)
    energy_modeling.calculate_energy_error(predictor.y_test, predictor.y_predict, aux_vars, labels=labels)
# Out:
# 2022-06-24 16:53:12,682 | INFO : R2: 0.1065
# 2022-06-24 16:53:12,685 | INFO : MAPE: 0.5981
# 2022-06-24 16:53:12,745 | INFO : R2: 0.2321
# 2022-06-24 16:53:12,745 | INFO : MAPE: 0.4172
# 2022-06-24 16:53:13,224 | INFO : R2: 0.3351
# 2022-06-24 16:53:13,225 | INFO : MAPE: 0.4475
# 2022-06-24 16:53:13,671 | INFO : R2: 0.3200
# 2022-06-24 16:53:13,672 | INFO : MAPE: 0.3725

# %%
for predictor in [regressor_fr, classifier_fr, regressor_nl, classifier_nl]:
    # aux_vars = pd.concat([predictor.aux_vars_test, predictor.X_test[['FootprintArea']]], axis=1, join="inner")
    labels = getattr(predictor, 'labels', None)
    y_true = pd.concat([predictor.y_test, predictor.aux_vars_test, predictor.X_test[['FootprintArea']]], axis=1, join="inner")
    y_pred = pd.concat([predictor.y_predict, predictor.aux_vars_test, predictor.X_test[['FootprintArea']]], axis=1, join="inner")

    energy_modeling.calculate_energy_error(y_true, y_pred, labels=labels)
# Out:
# 2022-06-24 17:37:48,276 | INFO : R2: 0.1828
# 2022-06-24 17:37:48,277 | INFO : MAPE: 0.4995
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2022-06-24 17:37:48,374 | INFO : R2: 0.3481
# 2022-06-24 17:37:48,374 | INFO : MAPE: 0.3235
# 2022-06-24 17:37:48,591 | WARNING : Building type information missing. Considering all buildings as residential.
# 2022-06-24 17:37:48,840 | WARNING : Building type information missing. Considering all buildings as residential.
# 2022-06-24 17:37:48,885 | INFO : R2: 0.3351
# 2022-06-24 17:37:48,886 | INFO : MAPE: 0.4475
# 2022-06-24 17:37:49,074 | WARNING : Building type information missing. Considering all buildings as residential.
# 2022-06-24 17:37:49,305 | WARNING : Building type information missing. Considering all buildings as residential.
# 2022-06-24 17:37:49,327 | INFO : R2: 0.3200
# 2022-06-24 17:37:49,328 | INFO : MAPE: 0.3725
