# %%
# standard libs
import os
import sys
import logging

# project lib
PROJECT_SRC_PATH = os.path.join(os.path.abspath(''), '..', 'src')
sys.path.append(PROJECT_SRC_PATH)

import utils
import dataset
import visualizations
from prediction_age import AgePredictor, AgeClassifier, AgePredictorComparison
from preprocessing import *
from fragmented_cities import *

# external libs
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import geopandas as gpd
from shapely import wkt

import shap

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, AdaBoostClassifier
from xgboost import XGBRegressor, XGBClassifier, XGBRFClassifier
# Out:
# /usr/local/Caskroom/miniconda/base/envs/uf-ml/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.

# %%
logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s', level=logging.INFO)

# %%
import warnings
warnings.filterwarnings('ignore', message='pandas.Int64Index is deprecated')
logging.captureWarnings(True)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data

# %%
overview_france = pd.read_csv(os.path.join('..', 'data', 'france_overview.csv'))
overview_netherlands = pd.read_csv(os.path.join('..', 'data', 'netherlands_overview.csv'))
overview_spain = pd.read_csv(os.path.join('..', 'data', 'spain_overview.csv'))
overview_finland = pd.read_csv(os.path.join('..', 'data', 'finland_overview.csv'))

# %%
gadm_france = gpd.read_file(os.path.join('..', 'data', 'gadm', 'gadm36_FRA_4.shp'))
gadm_netherlands = gpd.read_file(os.path.join('..', 'data', 'gadm', 'gadm36_NLD_2.shp'))
gadm_spain = gpd.read_file(os.path.join('..', 'data', 'gadm', 'gadm36_ESP_4.shp'))

# %%
file_gadm = os.path.join('..', 'data', 'gadm_table.csv')
gadm_info = pd.read_csv(file_gadm)

# %%
# respecting city fragmentation in France
gadm_france = gpd.read_file(os.path.join('..', 'data', 'gadm', 'gadm36_FRA_4_grouped_inc_lvl3.shp'))

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### 1. Aligning GADM regions with NUTS LAU regions

# %% [markdown]
# #### 1.1. Data

# %%
# Used for mapping GADM regions to LOCAL ADMINISTRATIVE UNITS (LAU) and to get their Degree of Urbanisation (DEGURBA)
lau_eu = gpd.read_file(os.path.join('..', 'data', 'geometry', 'LAU_RG_01M_2020_3035.shp'))
gadm_5_france = gpd.read_file(os.path.join('..', 'data', 'gadm', 'gadm36_FRA_5.shp'))

# %%
columns_of_interest = ['LAU CODE', 'POPULATION', 'DEGURBA']

lau_fr_classification = pd.read_csv(os.path.join('..', 'metadata', 'FR-LAU-2019.csv'), sep=';')[columns_of_interest]
lau_es_classification = pd.read_csv(os.path.join('..', 'metadata', 'ES-LAU-2019.csv'), sep=';')[columns_of_interest]
lau_nl_classification = pd.read_csv(os.path.join('..', 'metadata', 'NL-LAU-2019.csv'), sep=';')[columns_of_interest]

lau_fr_classification.dropna(subset=['LAU CODE'], inplace=True)
lau_es_classification.dropna(subset=['LAU CODE'], inplace=True)
lau_nl_classification.dropna(subset=['LAU CODE'], inplace=True)

lau_es_classification['LAU CODE'] = lau_es_classification['LAU CODE'].astype(str)
# Out:
# 2022-06-20 17:00:24,398 | WARNING : Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
lau_fr = lau_eu[lau_eu['CNTR_CODE'] == 'FR']
lau_es = lau_eu[lau_eu['CNTR_CODE'] == 'ES']
lau_nl = lau_eu[lau_eu['CNTR_CODE'] == 'NL']

len(gadm_5_france) - len(gadm_5_france.drop_duplicates(subset='NAME_5', keep=False))

len(gadm_5_france) - len(lau_fr)
len(gadm_spain) - len(lau_es)
len(gadm_netherlands) - len(lau_nl)
# Out:
# 0

# %% [markdown]
# #### 1.2. Mapping of GADM / LU regions based on spatial proximity

# %%
def nearest_lau_region(df, lau_geom_col='geometry_lau', gadm_lvl=5):
    gadm = df['geometry'].iloc[0].centroid
    lau = df[lau_geom_col].centroid

    dis = lau.distance(gadm)

    if dis.min() > 500:
        logger.info(f"No matching LAU region found for {df[f'GID_{gadm_lvl}'].iloc[0]}. Centroid of nearest NUTS LAU region ({df.iloc[dis.argmin()]['LAU_ID']}) is {int(dis.min())}m.")

    df['centroid_distance'] = dis.min()
    return df.iloc[[dis.argmin()]]


def join_nearest_lau_region(gadm_df, lau_df, gadm_lvl=5):
    gadm_df = gadm_df.to_crs(3035)
    lau_df['geometry_lau'] = lau_df.geometry

    # join overlapping & touching LAU regions to GADM regions (results in duplicate GADM GID samples if region has multiple LAU neighbors)
    gadm_df_joined = gpd.sjoin_nearest(gadm_df, lau_df[['LAU_ID', 'LAU_NAME', 'geometry', 'geometry_lau']], how='left', max_distance=10000, distance_col='sjoin_distance')

    gadm_islands = gadm_df_joined[gadm_df_joined['sjoin_distance'] > 0][f'NAME_{gadm_lvl}'].unique()
    if len(gadm_islands) > 0:
        logger.warning(f'GADM regions found without any LAU neighbors: {gadm_islands}')

    # distinct vs. ambiguous := overlapping / touching GADM and LAU regions with same vs. different name
    gadm_df_lau_distinct = gadm_df_joined[gadm_df_joined[f'NAME_{gadm_lvl}'] == gadm_df_joined['LAU_NAME']]
    gadm_df_lau_distinct.drop_duplicates(f'GID_{gadm_lvl}', keep=False, inplace=True) # remove ambigiuous assignments, e.g. rare case that neighboring regions share same GADM lvl5 name
    gadm_df_lau_ambiguous = gadm_df_joined[~gadm_df_joined[f'GID_{gadm_lvl}'].isin(gadm_df_lau_distinct[f'GID_{gadm_lvl}'].unique())]

    # map nearest LAU region to ambiguous GADM regions
    gadm_df_lau_ambiguous_nearest = gadm_df_lau_ambiguous.groupby(f'GID_{gadm_lvl}', group_keys=False).apply(lambda group: nearest_lau_region(group, gadm_lvl=gadm_lvl))
    return pd.concat([gadm_df_lau_distinct, gadm_df_lau_ambiguous_nearest], axis=0)


def visualize_region_matching(m):
    # %matplotlib qt
    _, ax = plt.subplots(1, 1)
    m.plot(ax=ax, column='LAU_NAME') #, color='blue')#, legend=True)
    gpd.GeoDataFrame(m, geometry=m['geometry_lau'], crs=3035).plot(ax=ax, column='LAU_NAME', hatch="//", alpha=0.2)

# %%
gadm_5_france_lau = join_nearest_lau_region(gadm_5_france, lau_fr, gadm_lvl=5)
gadm_spain_lau = join_nearest_lau_region(gadm_spain, lau_es, gadm_lvl=4)
gadm_netherlands_lau = join_nearest_lau_region(gadm_netherlands, lau_nl, gadm_lvl=2)

gadm_5_france_lau = gadm_5_france_lau.merge(lau_fr_classification, left_on='LAU_ID', right_on='LAU CODE', how='left')
gadm_spain_lau = gadm_spain_lau.merge(lau_es_classification, left_on='LAU_ID', right_on='LAU CODE', how='left')
gadm_netherlands_lau = gadm_netherlands_lau.merge(lau_nl_classification, left_on='LAU_ID', right_on='LAU CODE', how='left')
# Out:
# 2022-06-20 17:01:34,882 | WARNING :
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2022-06-20 17:01:41,048 | WARNING :
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2022-06-20 17:01:41,114 | INFO : No matching LAU region found for FRA.1.1.1.2.16_1. Centroid of nearest NUTS LAU region (01286) is 896m.
# 2022-06-20 17:01:41,118 | INFO : No matching LAU region found for FRA.1.1.1.2.17_1. Centroid of nearest NUTS LAU region (01286) is 1499m.
# 2022-06-20 17:01:41,123 | INFO : No matching LAU region found for FRA.1.1.1.2.21_1. Centroid of nearest NUTS LAU region (01015) is 2049m.
# 2022-06-20 17:01:41,130 | INFO : No matching LAU region found for FRA.1.1.1.2.22_1. Centroid of nearest NUTS LAU region (01227) is 852m.
# 2022-06-20 17:01:41,135 | INFO : No matching LAU region found for FRA.1.1.1.2.3_1. Centroid of nearest NUTS LAU region (01015) is 1478m.
# 2022-06-20 17:01:41,140 | INFO : No matching LAU region found for FRA.1.1.1.3.10_1. Centroid of nearest NUTS LAU region (01082) is 4881m.
# 2022-06-20 17:01:41,145 | INFO : No matching LAU region found for FRA.1.1.1.3.11_1. Centroid of nearest NUTS LAU region (01036) is 1569m.
# 2022-06-20 17:01:41,149 | INFO : No matching LAU region found for FRA.1.1.1.3.13_1. Centroid of nearest NUTS LAU region (01036) is 4034m.
# 2022-06-20 17:01:41,154 | INFO : No matching LAU region found for FRA.1.1.1.3.14_1. Centroid of nearest NUTS LAU region (01453) is 1124m.
# 2022-06-20 17:01:41,158 | INFO : No matching LAU region found for FRA.1.1.1.3.2_1. Centroid of nearest NUTS LAU region (01022) is 3479m.
# 2022-06-20 17:01:41,162 | INFO : No matching LAU region found for FRA.1.1.1.3.4_1. Centroid of nearest NUTS LAU region (01453) is 3732m.
# 2022-06-20 17:01:41,166 | INFO : No matching LAU region found for FRA.1.1.1.3.6_1. Centroid of nearest NUTS LAU region (01415) is 2096m.
# 2022-06-20 17:01:41,170 | INFO : No matching LAU region found for FRA.1.1.1.3.7_1. Centroid of nearest NUTS LAU region (01453) is 1601m.
# 2022-06-20 17:01:41,175 | INFO : No matching LAU region found for FRA.1.1.1.3.8_1. Centroid of nearest NUTS LAU region (01330) is 3934m.
# 2022-06-20 17:01:41,179 | INFO : No matching LAU region found for FRA.1.1.1.4.3_1. Centroid of nearest NUTS LAU region (01185) is 1965m.
# 2022-06-20 17:01:41,183 | INFO : No matching LAU region found for FRA.1.1.1.4.4_1. Centroid of nearest NUTS LAU region (01185) is 3396m.
# 2022-06-20 17:01:41,187 | INFO : No matching LAU region found for FRA.1.1.1.4.6_1. Centroid of nearest NUTS LAU region (01311) is 3132m.
# 2022-06-20 17:01:41,191 | INFO : No matching LAU region found for FRA.1.1.1.6.10_1. Centroid of nearest NUTS LAU region (01338) is 987m.
# 2022-06-20 17:01:41,195 | INFO : No matching LAU region found for FRA.1.1.1.6.3_1. Centroid of nearest NUTS LAU region (01117) is 2509m.
# 2022-06-20 17:01:41,199 | INFO : No matching LAU region found for FRA.1.1.1.7.7_1. Centroid of nearest NUTS LAU region (01416) is 2684m.
# 2022-06-20 17:01:41,209 | INFO : No matching LAU region found for FRA.1.1.1.9.9_1. Centroid of nearest NUTS LAU region (01141) is 2115m.
# 2022-06-20 17:01:41,213 | INFO : No matching LAU region found for FRA.1.1.2.1.2_1. Centroid of nearest NUTS LAU region (01025) is 1140m.
# 2022-06-20 17:01:41,217 | INFO : No matching LAU region found for FRA.1.1.2.1.4_1. Centroid of nearest NUTS LAU region (01025) is 2649m.
# 2022-06-20 17:01:41,221 | INFO : No matching LAU region found for FRA.1.1.2.10.4_1. Centroid of nearest NUTS LAU region (01130) is 1409m.
# 2022-06-20 17:01:41,225 | INFO : No matching LAU region found for FRA.1.1.2.10.6_1. Centroid of nearest NUTS LAU region (01130) is 1611m.
# 2022-06-20 17:01:41,230 | INFO : No matching LAU region found for FRA.1.1.2.19.1_1. Centroid of nearest NUTS LAU region (01095) is 1257m.
# 2022-06-20 17:01:41,235 | INFO : No matching LAU region found for FRA.1.1.2.19.4_1. Centroid of nearest NUTS LAU region (39018) is 2703m.
# 2022-06-20 17:01:41,239 | INFO : No matching LAU region found for FRA.1.1.2.19.7_1. Centroid of nearest NUTS LAU region (01127) is 2137m.
# 2022-06-20 17:01:41,243 | INFO : No matching LAU region found for FRA.1.1.2.19.9_1. Centroid of nearest NUTS LAU region (01426) is 636m.
# 2022-06-20 17:01:41,259 | INFO : No matching LAU region found for FRA.1.1.3.1.6_1. Centroid of nearest NUTS LAU region (01114) is 2523m.
# 2022-06-20 17:01:41,262 | INFO : No matching LAU region found for FRA.1.1.4.1.11_1. Centroid of nearest NUTS LAU region (01215) is 1307m.
# 2022-06-20 17:01:41,266 | INFO : No matching LAU region found for FRA.1.1.4.1.1_1. Centroid of nearest NUTS LAU region (74109) is 2826m.
# 2022-06-20 17:01:41,269 | INFO : No matching LAU region found for FRA.1.1.4.1.4_1. Centroid of nearest NUTS LAU region (01033) is 2119m.
# 2022-06-20 17:01:41,273 | INFO : No matching LAU region found for FRA.1.1.4.1.7_1. Centroid of nearest NUTS LAU region (01215) is 1665m.
# 2022-06-20 17:01:41,278 | INFO : No matching LAU region found for FRA.1.1.4.2.10_1. Centroid of nearest NUTS LAU region (01060) is 3000m.
# 2022-06-20 17:01:41,282 | INFO : No matching LAU region found for FRA.1.1.4.2.2_1. Centroid of nearest NUTS LAU region (01080) is 1362m.
# 2022-06-20 17:01:41,286 | INFO : No matching LAU region found for FRA.1.1.4.2.5_1. Centroid of nearest NUTS LAU region (01080) is 1685m.
# 2022-06-20 17:01:41,290 | INFO : No matching LAU region found for FRA.1.1.4.2.6_1. Centroid of nearest NUTS LAU region (01187) is 2088m.
# 2022-06-20 17:01:41,294 | INFO : No matching LAU region found for FRA.1.1.4.2.9_1. Centroid of nearest NUTS LAU region (01187) is 4332m.
# 2022-06-20 17:01:41,298 | INFO : No matching LAU region found for FRA.1.1.4.4.5_1. Centroid of nearest NUTS LAU region (01204) is 1801m.
# 2022-06-20 17:01:41,302 | INFO : No matching LAU region found for FRA.1.1.4.4.6_1. Centroid of nearest NUTS LAU region (01204) is 1630m.
# 2022-06-20 17:01:41,320 | INFO : No matching LAU region found for FRA.1.10.2.10.1_1. Centroid of nearest NUTS LAU region (63226) is 1422m.
# 2022-06-20 17:01:41,331 | INFO : No matching LAU region found for FRA.1.10.2.15.6_1. Centroid of nearest NUTS LAU region (63226) is 1109m.
# 2022-06-20 17:01:41,353 | INFO : No matching LAU region found for FRA.1.10.3.3.6_1. Centroid of nearest NUTS LAU region (63452) is 1847m.
# 2022-06-20 17:01:41,357 | INFO : No matching LAU region found for FRA.1.10.3.4.1_1. Centroid of nearest NUTS LAU region (63160) is 754m.
# 2022-06-20 17:01:41,361 | INFO : No matching LAU region found for FRA.1.10.3.4.4_1. Centroid of nearest NUTS LAU region (63160) is 1507m.
# 2022-06-20 17:01:41,372 | INFO : No matching LAU region found for FRA.1.10.3.7.11_1. Centroid of nearest NUTS LAU region (63255) is 614m.
# 2022-06-20 17:01:41,377 | INFO : No matching LAU region found for FRA.1.10.3.7.12_1. Centroid of nearest NUTS LAU region (63255) is 1623m.
# 2022-06-20 17:01:41,383 | INFO : No matching LAU region found for FRA.1.10.3.8.17_1. Centroid of nearest NUTS LAU region (63448) is 1154m.
# 2022-06-20 17:01:41,386 | INFO : No matching LAU region found for FRA.1.10.3.8.3_1. Centroid of nearest NUTS LAU region (63340) is 3201m.
# 2022-06-20 17:01:41,393 | INFO : No matching LAU region found for FRA.1.10.4.11.1_1. Centroid of nearest NUTS LAU region (63244) is 878m.
# 2022-06-20 17:01:41,397 | INFO : No matching LAU region found for FRA.1.10.4.11.3_1. Centroid of nearest NUTS LAU region (63244) is 1558m.
# 2022-06-20 17:01:41,421 | INFO : No matching LAU region found for FRA.1.11.1.10.1_1. Centroid of nearest NUTS LAU region (69123) is 1778m.
# 2022-06-20 17:01:41,425 | INFO : No matching LAU region found for FRA.1.11.1.11.1_1. Centroid of nearest NUTS LAU region (69123) is 994m.
# 2022-06-20 17:01:41,429 | INFO : No matching LAU region found for FRA.1.11.1.12.1_1. Centroid of nearest NUTS LAU region (69266) is 2457m.
# 2022-06-20 17:01:41,433 | INFO : No matching LAU region found for FRA.1.11.1.13.1_1. Centroid of nearest NUTS LAU region (69123) is 2832m.
# 2022-06-20 17:01:41,437 | INFO : No matching LAU region found for FRA.1.11.1.14.1_1. Centroid of nearest NUTS LAU region (69202) is 2355m.
# 2022-06-20 17:01:41,441 | INFO : No matching LAU region found for FRA.1.11.1.15.1_1. Centroid of nearest NUTS LAU region (69123) is 2354m.
# 2022-06-20 17:01:41,445 | INFO : No matching LAU region found for FRA.1.11.1.16.1_1. Centroid of nearest NUTS LAU region (69123) is 2368m.
# 2022-06-20 17:01:41,449 | INFO : No matching LAU region found for FRA.1.11.1.17.1_1. Centroid of nearest NUTS LAU region (69029) is 3339m.
# 2022-06-20 17:01:41,453 | INFO : No matching LAU region found for FRA.1.11.1.18.1_1. Centroid of nearest NUTS LAU region (69040) is 2466m.
# 2022-06-20 17:01:41,457 | INFO : No matching LAU region found for FRA.1.11.1.20.10_1. Centroid of nearest NUTS LAU region (69051) is 2003m.
# 2022-06-20 17:01:41,461 | INFO : No matching LAU region found for FRA.1.11.1.20.7_1. Centroid of nearest NUTS LAU region (69166) is 1441m.
# 2022-06-20 17:01:41,465 | INFO : No matching LAU region found for FRA.1.11.1.20.9_1. Centroid of nearest NUTS LAU region (69228) is 1793m.
# 2022-06-20 17:01:41,477 | INFO : No matching LAU region found for FRA.1.11.1.32.10_1. Centroid of nearest NUTS LAU region (69255) is 2394m.
# 2022-06-20 17:01:41,481 | INFO : No matching LAU region found for FRA.1.11.1.6.1_1. Centroid of nearest NUTS LAU region (69179) is 2635m.
# 2022-06-20 17:01:41,485 | INFO : No matching LAU region found for FRA.1.11.1.6.7_1. Centroid of nearest NUTS LAU region (69179) is 644m.
# 2022-06-20 17:01:41,489 | INFO : No matching LAU region found for FRA.1.11.1.6.8_1. Centroid of nearest NUTS LAU region (42083) is 1125m.
# 2022-06-20 17:01:41,493 | INFO : No matching LAU region found for FRA.1.11.1.8.11_1. Centroid of nearest NUTS LAU region (69208) is 1614m.
# 2022-06-20 17:01:41,497 | INFO : No matching LAU region found for FRA.1.11.1.8.13_1. Centroid of nearest NUTS LAU region (69208) is 500m.
# 2022-06-20 17:01:41,508 | INFO : No matching LAU region found for FRA.1.11.2.10.1_1. Centroid of nearest NUTS LAU region (69248) is 2854m.
# 2022-06-20 17:01:41,512 | INFO : No matching LAU region found for FRA.1.11.2.10.2_1. Centroid of nearest NUTS LAU region (69066) is 706m.
# 2022-06-20 17:01:41,516 | INFO : No matching LAU region found for FRA.1.11.2.10.3_1. Centroid of nearest NUTS LAU region (69248) is 2738m.
# 2022-06-20 17:01:41,520 | INFO : No matching LAU region found for FRA.1.11.2.10.4_1. Centroid of nearest NUTS LAU region (69248) is 2788m.
# 2022-06-20 17:01:41,525 | INFO : No matching LAU region found for FRA.1.11.2.10.5_1. Centroid of nearest NUTS LAU region (69248) is 1936m.
# 2022-06-20 17:01:41,528 | INFO : No matching LAU region found for FRA.1.11.2.10.6_1. Centroid of nearest NUTS LAU region (69248) is 2435m.
# 2022-06-20 17:01:41,532 | INFO : No matching LAU region found for FRA.1.11.2.10.8_1. Centroid of nearest NUTS LAU region (69248) is 2169m.
# 2022-06-20 17:01:41,536 | INFO : No matching LAU region found for FRA.1.11.2.2.14_1. Centroid of nearest NUTS LAU region (69159) is 1097m.
# 2022-06-20 17:01:41,540 | INFO : No matching LAU region found for FRA.1.11.2.2.8_1. Centroid of nearest NUTS LAU region (69159) is 1231m.
# 2022-06-20 17:01:41,547 | INFO : No matching LAU region found for FRA.1.11.2.3.1_1. Centroid of nearest NUTS LAU region (69258) is 3782m.
# 2022-06-20 17:01:41,550 | INFO : No matching LAU region found for FRA.1.11.2.4.11_1. Centroid of nearest NUTS LAU region (69019) is 1341m.
# 2022-06-20 17:01:41,554 | INFO : No matching LAU region found for FRA.1.11.2.4.1_1. Centroid of nearest NUTS LAU region (69019) is 1505m.
# 2022-06-20 17:01:41,560 | INFO : No matching LAU region found for FRA.1.11.2.6.10_1. Centroid of nearest NUTS LAU region (69066) is 2392m.
# 2022-06-20 17:01:41,564 | INFO : No matching LAU region found for FRA.1.11.2.7.12_1. Centroid of nearest NUTS LAU region (69024) is 1750m.
# 2022-06-20 17:01:41,568 | INFO : No matching LAU region found for FRA.1.11.2.7.13_1. Centroid of nearest NUTS LAU region (69024) is 823m.
# 2022-06-20 17:01:41,572 | INFO : No matching LAU region found for FRA.1.11.2.7.6_1. Centroid of nearest NUTS LAU region (69159) is 1391m.
# 2022-06-20 17:01:41,576 | INFO : No matching LAU region found for FRA.1.11.2.7.7_1. Centroid of nearest NUTS LAU region (69111) is 1676m.
# 2022-06-20 17:01:41,582 | INFO : No matching LAU region found for FRA.1.11.2.8.11_1. Centroid of nearest NUTS LAU region (71217) is 2554m.
# 2022-06-20 17:01:41,586 | INFO : No matching LAU region found for FRA.1.11.2.8.12_1. Centroid of nearest NUTS LAU region (69135) is 1602m.
# 2022-06-20 17:01:41,590 | INFO : No matching LAU region found for FRA.1.11.2.8.13_1. Centroid of nearest NUTS LAU region (71217) is 2316m.
# 2022-06-20 17:01:41,594 | INFO : No matching LAU region found for FRA.1.11.2.8.4_1. Centroid of nearest NUTS LAU region (69135) is 3787m.
# 2022-06-20 17:01:41,598 | INFO : No matching LAU region found for FRA.1.11.2.8.5_1. Centroid of nearest NUTS LAU region (69135) is 2001m.
# 2022-06-20 17:01:41,602 | INFO : No matching LAU region found for FRA.1.11.2.8.8_1. Centroid of nearest NUTS LAU region (69135) is 2999m.
# 2022-06-20 17:01:41,609 | INFO : No matching LAU region found for FRA.1.11.2.9.3_1. Centroid of nearest NUTS LAU region (69157) is 1510m.
# 2022-06-20 17:01:41,612 | INFO : No matching LAU region found for FRA.1.11.2.9.6_1. Centroid of nearest NUTS LAU region (69173) is 2386m.
# 2022-06-20 17:01:41,619 | INFO : No matching LAU region found for FRA.1.11.2.9.8_1. Centroid of nearest NUTS LAU region (69157) is 1718m.
# 2022-06-20 17:01:41,623 | INFO : No matching LAU region found for FRA.1.12.1.1.1_1. Centroid of nearest NUTS LAU region (73006) is 1597m.
# 2022-06-20 17:01:41,627 | INFO : No matching LAU region found for FRA.1.12.1.1.2_1. Centroid of nearest NUTS LAU region (73150) is 3558m.
# 2022-06-20 17:01:41,631 | INFO : No matching LAU region found for FRA.1.12.1.1.3_1. Centroid of nearest NUTS LAU region (73006) is 3985m.
# 2022-06-20 17:01:41,635 | INFO : No matching LAU region found for FRA.1.12.1.1.4_1. Centroid of nearest NUTS LAU region (73077) is 3479m.
# 2022-06-20 17:01:41,639 | INFO : No matching LAU region found for FRA.1.12.1.1.6_1. Centroid of nearest NUTS LAU region (73150) is 3676m.
# 2022-06-20 17:01:41,643 | INFO : No matching LAU region found for FRA.1.12.1.1.7_1. Centroid of nearest NUTS LAU region (73131) is 3342m.
# 2022-06-20 17:01:41,647 | INFO : No matching LAU region found for FRA.1.12.1.1.9_1. Centroid of nearest NUTS LAU region (73077) is 2233m.
# 2022-06-20 17:01:41,658 | INFO : No matching LAU region found for FRA.1.12.1.7.10_1. Centroid of nearest NUTS LAU region (73227) is 889m.
# 2022-06-20 17:01:41,662 | INFO : No matching LAU region found for FRA.1.12.1.7.5_1. Centroid of nearest NUTS LAU region (73057) is 3332m.
# 2022-06-20 17:01:41,668 | INFO : No matching LAU region found for FRA.1.12.1.9.11_1. Centroid of nearest NUTS LAU region (73024) is 6100m.
# 2022-06-20 17:01:41,671 | INFO : No matching LAU region found for FRA.1.12.1.9.13_1. Centroid of nearest NUTS LAU region (73257) is 2785m.
# 2022-06-20 17:01:41,675 | INFO : No matching LAU region found for FRA.1.12.1.9.14_1. Centroid of nearest NUTS LAU region (73003) is 2339m.
# 2022-06-20 17:01:41,679 | INFO : No matching LAU region found for FRA.1.12.1.9.15_1. Centroid of nearest NUTS LAU region (73284) is 938m.
# 2022-06-20 17:01:41,682 | INFO : No matching LAU region found for FRA.1.12.1.9.16_1. Centroid of nearest NUTS LAU region (73284) is 1820m.
# 2022-06-20 17:01:41,686 | INFO : No matching LAU region found for FRA.1.12.1.9.1_1. Centroid of nearest NUTS LAU region (73003) is 1077m.
# 2022-06-20 17:01:41,691 | INFO : No matching LAU region found for FRA.1.12.1.9.2_1. Centroid of nearest NUTS LAU region (73187) is 2732m.
# 2022-06-20 17:01:41,695 | INFO : No matching LAU region found for FRA.1.12.1.9.3_1. Centroid of nearest NUTS LAU region (73063) is 3931m.
# 2022-06-20 17:01:41,698 | INFO : No matching LAU region found for FRA.1.12.1.9.4_1. Centroid of nearest NUTS LAU region (73284) is 923m.
# 2022-06-20 17:01:41,702 | INFO : No matching LAU region found for FRA.1.12.1.9.7_1. Centroid of nearest NUTS LAU region (73003) is 3103m.
# 2022-06-20 17:01:41,709 | INFO : No matching LAU region found for FRA.1.12.2.1.5_1. Centroid of nearest NUTS LAU region (73263) is 1423m.
# 2022-06-20 17:01:41,714 | INFO : No matching LAU region found for FRA.1.12.2.1.6_1. Centroid of nearest NUTS LAU region (73263) is 1521m.
# 2022-06-20 17:01:41,725 | INFO : No matching LAU region found for FRA.1.12.2.11.4_1. Centroid of nearest NUTS LAU region (73217) is 946m.
# 2022-06-20 17:01:41,733 | INFO : No matching LAU region found for FRA.1.12.2.11.7_1. Centroid of nearest NUTS LAU region (73215) is 950m.
# 2022-06-20 17:01:41,762 | INFO : No matching LAU region found for FRA.1.12.2.15.4_1. Centroid of nearest NUTS LAU region (73151) is 2058m.
# 2022-06-20 17:01:41,768 | INFO : No matching LAU region found for FRA.1.12.2.15.7_1. Centroid of nearest NUTS LAU region (73151) is 922m.
# 2022-06-20 17:01:41,777 | INFO : No matching LAU region found for FRA.1.12.2.18.4_1. Centroid of nearest NUTS LAU region (73236) is 607m.
# 2022-06-20 17:01:41,781 | INFO : No matching LAU region found for FRA.1.12.2.18.8_1. Centroid of nearest NUTS LAU region (73236) is 1910m.
# 2022-06-20 17:01:41,784 | INFO : No matching LAU region found for FRA.1.12.2.18.9_1. Centroid of nearest NUTS LAU region (73236) is 2667m.
# 2022-06-20 17:01:41,796 | INFO : No matching LAU region found for FRA.1.12.2.4.1_1. Centroid of nearest NUTS LAU region (73010) is 1647m.
# 2022-06-20 17:01:41,799 | INFO : No matching LAU region found for FRA.1.12.2.4.2_1. Centroid of nearest NUTS LAU region (74170) is 2908m.
# 2022-06-20 17:01:41,804 | INFO : No matching LAU region found for FRA.1.12.2.4.3_1. Centroid of nearest NUTS LAU region (73265) is 2520m.
# 2022-06-20 17:01:41,810 | INFO : No matching LAU region found for FRA.1.12.2.4.5_1. Centroid of nearest NUTS LAU region (73043) is 2914m.
# 2022-06-20 17:01:41,813 | INFO : No matching LAU region found for FRA.1.12.2.4.6_1. Centroid of nearest NUTS LAU region (73010) is 3083m.
# 2022-06-20 17:01:41,817 | INFO : No matching LAU region found for FRA.1.12.2.4.7_1. Centroid of nearest NUTS LAU region (74054) is 1798m.
# 2022-06-20 17:01:41,830 | INFO : No matching LAU region found for FRA.1.12.3.1.1_1. Centroid of nearest NUTS LAU region (73212) is 1581m.
# 2022-06-20 17:01:41,834 | INFO : No matching LAU region found for FRA.1.12.3.1.8_1. Centroid of nearest NUTS LAU region (73212) is 619m.
# 2022-06-20 17:01:41,841 | INFO : No matching LAU region found for FRA.1.12.3.2.11_1. Centroid of nearest NUTS LAU region (73235) is 2320m.
# 2022-06-20 17:01:41,852 | INFO : No matching LAU region found for FRA.1.12.3.2.4_1. Centroid of nearest NUTS LAU region (73235) is 2384m.
# 2022-06-20 17:01:41,856 | INFO : No matching LAU region found for FRA.1.12.3.2.5_1. Centroid of nearest NUTS LAU region (73235) is 2804m.
# 2022-06-20 17:01:41,860 | INFO : No matching LAU region found for FRA.1.12.3.3.3_1. Centroid of nearest NUTS LAU region (73026) is 7690m.
# 2022-06-20 17:01:41,864 | INFO : No matching LAU region found for FRA.1.12.3.3.4_1. Centroid of nearest NUTS LAU region (73290) is 5875m.
# 2022-06-20 17:01:41,868 | INFO : No matching LAU region found for FRA.1.12.3.3.5_1. Centroid of nearest NUTS LAU region (73290) is 5540m.
# 2022-06-20 17:01:41,872 | INFO : No matching LAU region found for FRA.1.12.3.3.6_1. Centroid of nearest NUTS LAU region (73290) is 5237m.
# 2022-06-20 17:01:41,875 | INFO : No matching LAU region found for FRA.1.12.3.3.7_1. Centroid of nearest NUTS LAU region (73290) is 7653m.
# 2022-06-20 17:01:41,879 | INFO : No matching LAU region found for FRA.1.12.3.5.4_1. Centroid of nearest NUTS LAU region (73135) is 1904m.
# 2022-06-20 17:01:41,883 | INFO : No matching LAU region found for FRA.1.12.3.5.6_1. Centroid of nearest NUTS LAU region (73135) is 782m.
# 2022-06-20 17:01:41,887 | INFO : No matching LAU region found for FRA.1.12.3.5.9_1. Centroid of nearest NUTS LAU region (73177) is 1271m.
# 2022-06-20 17:01:41,891 | INFO : No matching LAU region found for FRA.1.2.1.1.12_1. Centroid of nearest NUTS LAU region (03168) is 2043m.
# 2022-06-20 17:01:41,898 | INFO : No matching LAU region found for FRA.1.2.1.1.7_1. Centroid of nearest NUTS LAU region (03168) is 2873m.
# 2022-06-20 17:01:41,902 | INFO : No matching LAU region found for FRA.1.2.1.5.10_1. Centroid of nearest NUTS LAU region (03158) is 3018m.
# 2022-06-20 17:01:41,906 | INFO : No matching LAU region found for FRA.1.2.1.5.5_1. Centroid of nearest NUTS LAU region (03158) is 2926m.
# 2022-06-20 17:01:41,912 | INFO : No matching LAU region found for FRA.1.2.1.5.9_1. Centroid of nearest NUTS LAU region (03158) is 2987m.
# 2022-06-20 17:01:41,956 | INFO : No matching LAU region found for FRA.1.3.1.1.2_1. Centroid of nearest NUTS LAU region (07011) is 1830m.
# 2022-06-20 17:01:41,960 | INFO : No matching LAU region found for FRA.1.3.1.1.3_1. Centroid of nearest NUTS LAU region (07011) is 3054m.
# 2022-06-20 17:01:41,979 | INFO : No matching LAU region found for FRA.1.3.1.9.3_1. Centroid of nearest NUTS LAU region (07262) is 2234m.
# 2022-06-20 17:01:41,985 | INFO : No matching LAU region found for FRA.1.3.1.9.8_1. Centroid of nearest NUTS LAU region (07262) is 772m.
# 2022-06-20 17:01:42,003 | INFO : No matching LAU region found for FRA.1.3.3.5.13_1. Centroid of nearest NUTS LAU region (07165) is 1409m.
# 2022-06-20 17:01:42,012 | INFO : No matching LAU region found for FRA.1.3.3.5.7_1. Centroid of nearest NUTS LAU region (07222) is 1790m.
# 2022-06-20 17:01:42,015 | INFO : No matching LAU region found for FRA.1.3.3.8.4_1. Centroid of nearest NUTS LAU region (07103) is 1009m.
# 2022-06-20 17:01:42,021 | INFO : No matching LAU region found for FRA.1.3.3.8.9_1. Centroid of nearest NUTS LAU region (07103) is 998m.
# 2022-06-20 17:01:42,027 | INFO : No matching LAU region found for FRA.1.4.1.10.3_1. Centroid of nearest NUTS LAU region (15268) is 2944m.
# 2022-06-20 17:01:42,031 | INFO : No matching LAU region found for FRA.1.4.1.10.7_1. Centroid of nearest NUTS LAU region (15268) is 1254m.
# 2022-06-20 17:01:42,035 | INFO : No matching LAU region found for FRA.1.4.1.7.11_1. Centroid of nearest NUTS LAU region (15181) is 999m.
# 2022-06-20 17:01:42,039 | INFO : No matching LAU region found for FRA.1.4.1.7.2_1. Centroid of nearest NUTS LAU region (15181) is 3120m.
# 2022-06-20 17:01:42,046 | INFO : No matching LAU region found for FRA.1.4.1.7.7_1. Centroid of nearest NUTS LAU region (15027) is 1400m.
# 2022-06-20 17:01:42,050 | INFO : No matching LAU region found for FRA.1.4.1.8.1_1. Centroid of nearest NUTS LAU region (15027) is 3048m.
# 2022-06-20 17:01:42,067 | INFO : No matching LAU region found for FRA.1.4.3.1.8_1. Centroid of nearest NUTS LAU region (15080) is 3481m.
# 2022-06-20 17:01:42,078 | INFO : No matching LAU region found for FRA.1.4.3.5.14_1. Centroid of nearest NUTS LAU region (15141) is 3878m.
# 2022-06-20 17:01:42,082 | INFO : No matching LAU region found for FRA.1.4.3.5.2_1. Centroid of nearest NUTS LAU region (15041) is 3527m.
# 2022-06-20 17:01:42,086 | INFO : No matching LAU region found for FRA.1.4.3.5.3_1. Centroid of nearest NUTS LAU region (15141) is 1597m.
# 2022-06-20 17:01:42,090 | INFO : No matching LAU region found for FRA.1.4.3.5.4_1. Centroid of nearest NUTS LAU region (15138) is 1042m.
# 2022-06-20 17:01:42,094 | INFO : No matching LAU region found for FRA.1.4.3.5.5_1. Centroid of nearest NUTS LAU region (15263) is 4088m.
# 2022-06-20 17:01:42,100 | INFO : No matching LAU region found for FRA.1.4.3.6.7_1. Centroid of nearest NUTS LAU region (15077) is 3642m.
# 2022-06-20 17:01:42,104 | INFO : No matching LAU region found for FRA.1.4.3.7.10_1. Centroid of nearest NUTS LAU region (48002) is 4007m.
# 2022-06-20 17:01:42,109 | INFO : No matching LAU region found for FRA.1.4.3.7.11_1. Centroid of nearest NUTS LAU region (15108) is 2275m.
# 2022-06-20 17:01:42,112 | INFO : No matching LAU region found for FRA.1.4.3.7.5_1. Centroid of nearest NUTS LAU region (15108) is 3039m.
# 2022-06-20 17:01:42,116 | INFO : No matching LAU region found for FRA.1.4.3.7.7_1. Centroid of nearest NUTS LAU region (15108) is 2644m.
# 2022-06-20 17:01:42,120 | INFO : No matching LAU region found for FRA.1.4.3.9.3_1. Centroid of nearest NUTS LAU region (15142) is 4873m.
# 2022-06-20 17:01:42,129 | INFO : No matching LAU region found for FRA.1.4.3.9.7_1. Centroid of nearest NUTS LAU region (15262) is 3296m.
# 2022-06-20 17:01:42,140 | INFO : No matching LAU region found for FRA.1.5.1.2.7_1. Centroid of nearest NUTS LAU region (26086) is 1478m.
# 2022-06-20 17:01:42,148 | INFO : No matching LAU region found for FRA.1.5.1.6.1_1. Centroid of nearest NUTS LAU region (26001) is 549m.
# 2022-06-20 17:01:42,152 | INFO : No matching LAU region found for FRA.1.5.1.6.7_1. Centroid of nearest NUTS LAU region (26001) is 2700m.
# 2022-06-20 17:01:42,210 | INFO : No matching LAU region found for FRA.1.5.3.13.10_1. Centroid of nearest NUTS LAU region (26179) is 525m.
# 2022-06-20 17:01:42,213 | INFO : No matching LAU region found for FRA.1.5.3.13.14_1. Centroid of nearest NUTS LAU region (26092) is 2245m.
# 2022-06-20 17:01:42,227 | INFO : No matching LAU region found for FRA.1.5.3.4.7_1. Centroid of nearest NUTS LAU region (26210) is 1210m.
# 2022-06-20 17:01:42,233 | INFO : No matching LAU region found for FRA.1.5.3.8.5_1. Centroid of nearest NUTS LAU region (26310) is 2203m.
# 2022-06-20 17:01:42,237 | INFO : No matching LAU region found for FRA.1.5.3.8.8_1. Centroid of nearest NUTS LAU region (26210) is 2416m.
# 2022-06-20 17:01:42,243 | INFO : No matching LAU region found for FRA.1.6.1.11.12_1. Centroid of nearest NUTS LAU region (43090) is 1636m.
# 2022-06-20 17:01:42,246 | INFO : No matching LAU region found for FRA.1.6.1.11.2_1. Centroid of nearest NUTS LAU region (43220) is 3469m.
# 2022-06-20 17:01:42,250 | INFO : No matching LAU region found for FRA.1.6.1.11.4_1. Centroid of nearest NUTS LAU region (43090) is 1077m.
# 2022-06-20 17:01:42,275 | INFO : No matching LAU region found for FRA.1.6.2.3.5_1. Centroid of nearest NUTS LAU region (43221) is 2616m.
# 2022-06-20 17:01:42,299 | INFO : No matching LAU region found for FRA.1.7.1.2.10_1. Centroid of nearest NUTS LAU region (74112) is 2079m.
# 2022-06-20 17:01:42,303 | INFO : No matching LAU region found for FRA.1.7.1.2.11_1. Centroid of nearest NUTS LAU region (74062) is 1879m.
# 2022-06-20 17:01:42,306 | INFO : No matching LAU region found for FRA.1.7.1.2.12_1. Centroid of nearest NUTS LAU region (74275) is 1843m.
# 2022-06-20 17:01:42,310 | INFO : No matching LAU region found for FRA.1.7.1.2.2_1. Centroid of nearest NUTS LAU region (74198) is 3178m.
# 2022-06-20 17:01:42,314 | INFO : No matching LAU region found for FRA.1.7.1.3.2_1. Centroid of nearest NUTS LAU region (74112) is 826m.
# 2022-06-20 17:01:42,320 | INFO : No matching LAU region found for FRA.1.7.1.3.6_1. Centroid of nearest NUTS LAU region (74112) is 1059m.
# 2022-06-20 17:01:42,324 | INFO : No matching LAU region found for FRA.1.7.1.3.7_1. Centroid of nearest NUTS LAU region (74010) is 2510m.
# 2022-06-20 17:01:42,328 | INFO : No matching LAU region found for FRA.1.7.1.5.10_1. Centroid of nearest NUTS LAU region (74123) is 2087m.
# 2022-06-20 17:01:42,331 | INFO : No matching LAU region found for FRA.1.7.1.5.2_1. Centroid of nearest NUTS LAU region (74167) is 2359m.
# 2022-06-20 17:01:42,335 | INFO : No matching LAU region found for FRA.1.7.1.5.4_1. Centroid of nearest NUTS LAU region (74123) is 2636m.
# 2022-06-20 17:01:42,340 | INFO : No matching LAU region found for FRA.1.7.1.5.7_1. Centroid of nearest NUTS LAU region (74167) is 556m.
# 2022-06-20 17:01:42,344 | INFO : No matching LAU region found for FRA.1.7.1.5.8_1. Centroid of nearest NUTS LAU region (74275) is 2854m.
# 2022-06-20 17:01:42,348 | INFO : No matching LAU region found for FRA.1.7.1.6.15_1. Centroid of nearest NUTS LAU region (74151) is 1934m.
# 2022-06-20 17:01:42,351 | INFO : No matching LAU region found for FRA.1.7.1.6.16_1. Centroid of nearest NUTS LAU region (74289) is 2374m.
# 2022-06-20 17:01:42,358 | INFO : No matching LAU region found for FRA.1.7.1.7.12_1. Centroid of nearest NUTS LAU region (74186) is 2998m.
# 2022-06-20 17:01:42,362 | INFO : No matching LAU region found for FRA.1.7.1.7.2_1. Centroid of nearest NUTS LAU region (74010) is 1418m.
# 2022-06-20 17:01:42,381 | INFO : No matching LAU region found for FRA.1.7.1.9.1_1. Centroid of nearest NUTS LAU region (74282) is 2362m.
# 2022-06-20 17:01:42,385 | INFO : No matching LAU region found for FRA.1.7.1.9.2_1. Centroid of nearest NUTS LAU region (74059) is 3745m.
# 2022-06-20 17:01:42,389 | INFO : No matching LAU region found for FRA.1.7.1.9.4_1. Centroid of nearest NUTS LAU region (74062) is 2389m.
# 2022-06-20 17:01:42,393 | INFO : No matching LAU region found for FRA.1.7.1.9.5_1. Centroid of nearest NUTS LAU region (74282) is 3069m.
# 2022-06-20 17:01:42,397 | INFO : No matching LAU region found for FRA.1.7.2.1.5_1. Centroid of nearest NUTS LAU region (74239) is 3959m.
# 2022-06-20 17:01:42,401 | INFO : No matching LAU region found for FRA.1.7.2.1.7_1. Centroid of nearest NUTS LAU region (74212) is 1350m.
# 2022-06-20 17:01:42,425 | INFO : No matching LAU region found for FRA.1.7.3.1.1_1. Centroid of nearest NUTS LAU region (74218) is 2156m.
# 2022-06-20 17:01:42,449 | INFO : No matching LAU region found for FRA.1.8.1.1.3_1. Centroid of nearest NUTS LAU region (38163) is 2810m.
# 2022-06-20 17:01:42,455 | INFO : No matching LAU region found for FRA.1.8.1.1.5_1. Centroid of nearest NUTS LAU region (38006) is 4359m.
# 2022-06-20 17:01:42,459 | INFO : No matching LAU region found for FRA.1.8.1.1.6_1. Centroid of nearest NUTS LAU region (38439) is 564m.
# 2022-06-20 17:01:42,473 | INFO : No matching LAU region found for FRA.1.8.1.12.8_1. Centroid of nearest NUTS LAU region (38100) is 1595m.
# 2022-06-20 17:01:42,483 | INFO : No matching LAU region found for FRA.1.8.1.15.11_1. Centroid of nearest NUTS LAU region (38253) is 2602m.
# 2022-06-20 17:01:42,486 | INFO : No matching LAU region found for FRA.1.8.1.15.17_1. Centroid of nearest NUTS LAU region (38253) is 2718m.
# 2022-06-20 17:01:42,498 | INFO : No matching LAU region found for FRA.1.8.1.16.10_1. Centroid of nearest NUTS LAU region (38395) is 2456m.
# 2022-06-20 17:01:42,502 | INFO : No matching LAU region found for FRA.1.8.1.16.11_1. Centroid of nearest NUTS LAU region (38140) is 3448m.
# 2022-06-20 17:01:42,514 | INFO : No matching LAU region found for FRA.1.8.1.16.9_1. Centroid of nearest NUTS LAU region (38395) is 2411m.
# 2022-06-20 17:01:42,518 | INFO : No matching LAU region found for FRA.1.8.1.17.1_1. Centroid of nearest NUTS LAU region (38456) is 2205m.
# 2022-06-20 17:01:42,522 | INFO : No matching LAU region found for FRA.1.8.1.17.8_1. Centroid of nearest NUTS LAU region (38456) is 2842m.
# 2022-06-20 17:01:42,539 | INFO : No matching LAU region found for FRA.1.8.1.27.5_1. Centroid of nearest NUTS LAU region (38359) is 2145m.
# 2022-06-20 17:01:42,545 | INFO : No matching LAU region found for FRA.1.8.1.27.9_1. Centroid of nearest NUTS LAU region (38359) is 1380m.
# 2022-06-20 17:01:42,554 | INFO : No matching LAU region found for FRA.1.8.1.30.1_1. Centroid of nearest NUTS LAU region (38073) is 3059m.
# 2022-06-20 17:01:42,562 | INFO : No matching LAU region found for FRA.1.8.1.30.6_1. Centroid of nearest NUTS LAU region (38073) is 2168m.
# 2022-06-20 17:01:42,571 | INFO : No matching LAU region found for FRA.1.8.1.32.1_1. Centroid of nearest NUTS LAU region (38225) is 3272m.
# 2022-06-20 17:01:42,574 | INFO : No matching LAU region found for FRA.1.8.1.32.5_1. Centroid of nearest NUTS LAU region (38225) is 4205m.
# 2022-06-20 17:01:42,582 | INFO : No matching LAU region found for FRA.1.8.1.35.4_1. Centroid of nearest NUTS LAU region (38407) is 1199m.
# 2022-06-20 17:01:42,586 | INFO : No matching LAU region found for FRA.1.8.1.35.7_1. Centroid of nearest NUTS LAU region (38407) is 1923m.
# 2022-06-20 17:01:42,603 | INFO : No matching LAU region found for FRA.1.8.2.10.11_1. Centroid of nearest NUTS LAU region (38297) is 1446m.
# 2022-06-20 17:01:42,607 | INFO : No matching LAU region found for FRA.1.8.2.10.17_1. Centroid of nearest NUTS LAU region (38022) is 2427m.
# 2022-06-20 17:01:42,611 | INFO : No matching LAU region found for FRA.1.8.2.10.1_1. Centroid of nearest NUTS LAU region (38297) is 1548m.
# 2022-06-20 17:01:42,617 | INFO : No matching LAU region found for FRA.1.8.2.10.8_1. Centroid of nearest NUTS LAU region (38022) is 951m.
# 2022-06-20 17:01:42,621 | INFO : No matching LAU region found for FRA.1.8.2.11.2_1. Centroid of nearest NUTS LAU region (38080) is 2508m.
# 2022-06-20 17:01:42,625 | INFO : No matching LAU region found for FRA.1.8.2.11.6_1. Centroid of nearest NUTS LAU region (38292) is 2005m.
# 2022-06-20 17:01:42,629 | INFO : No matching LAU region found for FRA.1.8.2.12.11_1. Centroid of nearest NUTS LAU region (38047) is 1893m.
# 2022-06-20 17:01:42,633 | INFO : No matching LAU region found for FRA.1.8.2.12.14_1. Centroid of nearest NUTS LAU region (38560) is 918m.
# 2022-06-20 17:01:42,639 | INFO : No matching LAU region found for FRA.1.8.2.12.8_1. Centroid of nearest NUTS LAU region (38292) is 2330m.
# 2022-06-20 17:01:42,643 | INFO : No matching LAU region found for FRA.1.8.2.2.1_1. Centroid of nearest NUTS LAU region (38152) is 1408m.
# 2022-06-20 17:01:42,662 | INFO : No matching LAU region found for FRA.1.8.2.9.4_1. Centroid of nearest NUTS LAU region (38357) is 2625m.
# 2022-06-20 17:01:42,670 | INFO : No matching LAU region found for FRA.1.8.2.9.8_1. Centroid of nearest NUTS LAU region (38001) is 1032m.
# 2022-06-20 17:01:42,677 | INFO : No matching LAU region found for FRA.1.8.3.3.10_1. Centroid of nearest NUTS LAU region (38069) is 2947m.
# 2022-06-20 17:01:42,681 | INFO : No matching LAU region found for FRA.1.8.3.3.11_1. Centroid of nearest NUTS LAU region (38284) is 1071m.
# 2022-06-20 17:01:42,685 | INFO : No matching LAU region found for FRA.1.8.3.3.16_1. Centroid of nearest NUTS LAU region (38479) is 1557m.
# 2022-06-20 17:01:42,689 | INFO : No matching LAU region found for FRA.1.8.3.3.1_1. Centroid of nearest NUTS LAU region (38049) is 2243m.
# 2022-06-20 17:01:42,693 | INFO : No matching LAU region found for FRA.1.8.3.3.2_1. Centroid of nearest NUTS LAU region (38284) is 780m.
# 2022-06-20 17:01:42,697 | INFO : No matching LAU region found for FRA.1.8.3.3.5_1. Centroid of nearest NUTS LAU region (38479) is 1153m.
# 2022-06-20 17:01:42,708 | INFO : No matching LAU region found for FRA.1.8.3.6.5_1. Centroid of nearest NUTS LAU region (38152) is 828m.
# 2022-06-20 17:01:42,728 | INFO : No matching LAU region found for FRA.1.9.1.5.10_1. Centroid of nearest NUTS LAU region (42245) is 1875m.
# 2022-06-20 17:01:42,731 | INFO : No matching LAU region found for FRA.1.9.1.5.12_1. Centroid of nearest NUTS LAU region (42217) is 3271m.
# 2022-06-20 17:01:42,751 | INFO : No matching LAU region found for FRA.1.9.1.8.1_1. Centroid of nearest NUTS LAU region (42039) is 1036m.
# 2022-06-20 17:01:42,755 | INFO : No matching LAU region found for FRA.1.9.1.8.3_1. Centroid of nearest NUTS LAU region (42039) is 3039m.
# 2022-06-20 17:01:42,780 | INFO : No matching LAU region found for FRA.1.9.2.9.12_1. Centroid of nearest NUTS LAU region (42268) is 2271m.
# 2022-06-20 17:01:42,783 | INFO : No matching LAU region found for FRA.1.9.2.9.1_1. Centroid of nearest NUTS LAU region (42268) is 1547m.
# 2022-06-20 17:01:42,787 | INFO : No matching LAU region found for FRA.1.9.2.9.3_1. Centroid of nearest NUTS LAU region (42268) is 2656m.
# 2022-06-20 17:01:42,821 | INFO : No matching LAU region found for FRA.10.1.1.2.10_1. Centroid of nearest NUTS LAU region (17295) is 1529m.
# 2022-06-20 17:01:42,826 | INFO : No matching LAU region found for FRA.10.1.1.2.13_1. Centroid of nearest NUTS LAU region (17295) is 1327m.
# 2022-06-20 17:01:42,830 | INFO : No matching LAU region found for FRA.10.1.1.2.16_1. Centroid of nearest NUTS LAU region (17295) is 1736m.
# 2022-06-20 17:01:42,875 | INFO : No matching LAU region found for FRA.10.1.3.12.11_1. Centroid of nearest NUTS LAU region (17457) is 1932m.
# 2022-06-20 17:01:42,878 | INFO : No matching LAU region found for FRA.10.1.3.12.3_1. Centroid of nearest NUTS LAU region (17340) is 1985m.
# 2022-06-20 17:01:42,891 | INFO : No matching LAU region found for FRA.10.1.3.4.2_1. Centroid of nearest NUTS LAU region (17219) is 1863m.
# 2022-06-20 17:01:42,897 | INFO : No matching LAU region found for FRA.10.1.3.4.4_1. Centroid of nearest NUTS LAU region (17219) is 3160m.
# 2022-06-20 17:01:42,922 | INFO : No matching LAU region found for FRA.10.1.4.4.7_1. Centroid of nearest NUTS LAU region (17181) is 1982m.
# 2022-06-20 17:01:42,925 | INFO : No matching LAU region found for FRA.10.1.4.5.12_1. Centroid of nearest NUTS LAU region (17277) is 1219m.
# 2022-06-20 17:01:42,929 | INFO : No matching LAU region found for FRA.10.1.4.5.6_1. Centroid of nearest NUTS LAU region (17277) is 2029m.
# 2022-06-20 17:01:42,941 | INFO : No matching LAU region found for FRA.10.1.4.7.3_1. Centroid of nearest NUTS LAU region (17457) is 2356m.
# 2022-06-20 17:01:42,945 | INFO : No matching LAU region found for FRA.10.1.4.7.8_1. Centroid of nearest NUTS LAU region (17457) is 2471m.
# 2022-06-20 17:01:42,955 | INFO : No matching LAU region found for FRA.10.1.5.2.12_1. Centroid of nearest NUTS LAU region (17160) is 3066m.
# 2022-06-20 17:01:42,999 | INFO : No matching LAU region found for FRA.10.11.2.2.1_1. Centroid of nearest NUTS LAU region (64225) is 1534m.
# 2022-06-20 17:01:43,015 | INFO : No matching LAU region found for FRA.10.11.2.2.4_1. Centroid of nearest NUTS LAU region (64225) is 1192m.
# 2022-06-20 17:01:43,029 | INFO : No matching LAU region found for FRA.10.12.1.1.1_1. Centroid of nearest NUTS LAU region (86245) is 1486m.
# 2022-06-20 17:01:43,039 | INFO : No matching LAU region found for FRA.10.12.1.13.3_1. Centroid of nearest NUTS LAU region (86019) is 1803m.
# 2022-06-20 17:01:43,043 | INFO : No matching LAU region found for FRA.10.12.1.3.2_1. Centroid of nearest NUTS LAU region (86245) is 2625m.
# 2022-06-20 17:01:43,062 | INFO : No matching LAU region found for FRA.10.12.2.5.3_1. Centroid of nearest NUTS LAU region (86082) is 1984m.
# 2022-06-20 17:01:43,066 | INFO : No matching LAU region found for FRA.10.12.2.5.4_1. Centroid of nearest NUTS LAU region (86082) is 1861m.
# 2022-06-20 17:01:43,070 | INFO : No matching LAU region found for FRA.10.12.2.5.6_1. Centroid of nearest NUTS LAU region (86082) is 3277m.
# 2022-06-20 17:01:43,074 | INFO : No matching LAU region found for FRA.10.12.2.5.7_1. Centroid of nearest NUTS LAU region (86296) is 4264m.
# 2022-06-20 17:01:43,077 | INFO : No matching LAU region found for FRA.10.12.2.5.9_1. Centroid of nearest NUTS LAU region (86082) is 3976m.
# 2022-06-20 17:01:43,093 | INFO : No matching LAU region found for FRA.10.12.3.13.2_1. Centroid of nearest NUTS LAU region (86115) is 2541m.
# 2022-06-20 17:01:43,096 | INFO : No matching LAU region found for FRA.10.12.3.13.3_1. Centroid of nearest NUTS LAU region (86019) is 2693m.
# 2022-06-20 17:01:43,103 | INFO : No matching LAU region found for FRA.10.12.3.16.10_1. Centroid of nearest NUTS LAU region (86053) is 2444m.
# 2022-06-20 17:01:43,106 | INFO : No matching LAU region found for FRA.10.12.3.16.12_1. Centroid of nearest NUTS LAU region (86123) is 4006m.
# 2022-06-20 17:01:43,110 | INFO : No matching LAU region found for FRA.10.12.3.16.2_1. Centroid of nearest NUTS LAU region (86123) is 4071m.
# 2022-06-20 17:01:43,114 | INFO : No matching LAU region found for FRA.10.12.3.16.7_1. Centroid of nearest NUTS LAU region (86083) is 4320m.
# 2022-06-20 17:01:43,117 | INFO : No matching LAU region found for FRA.10.12.3.16.9_1. Centroid of nearest NUTS LAU region (86123) is 516m.
# 2022-06-20 17:01:43,121 | INFO : No matching LAU region found for FRA.10.12.3.3.2_1. Centroid of nearest NUTS LAU region (86053) is 904m.
# 2022-06-20 17:01:43,126 | INFO : No matching LAU region found for FRA.10.12.3.3.9_1. Centroid of nearest NUTS LAU region (86160) is 2985m.
# 2022-06-20 17:01:43,130 | INFO : No matching LAU region found for FRA.10.12.3.4.2_1. Centroid of nearest NUTS LAU region (86281) is 2227m.
# 2022-06-20 17:01:43,134 | INFO : No matching LAU region found for FRA.10.12.3.4.4_1. Centroid of nearest NUTS LAU region (86300) is 2823m.
# 2022-06-20 17:01:43,137 | INFO : No matching LAU region found for FRA.10.12.3.4.5_1. Centroid of nearest NUTS LAU region (86281) is 2003m.
# 2022-06-20 17:01:43,141 | INFO : No matching LAU region found for FRA.10.12.3.4.7_1. Centroid of nearest NUTS LAU region (86115) is 3208m.
# 2022-06-20 17:01:43,145 | INFO : No matching LAU region found for FRA.10.12.3.4.9_1. Centroid of nearest NUTS LAU region (86048) is 3400m.
# 2022-06-20 17:01:43,148 | INFO : No matching LAU region found for FRA.10.2.1.10.10_1. Centroid of nearest NUTS LAU region (16230) is 2347m.
# 2022-06-20 17:01:43,152 | INFO : No matching LAU region found for FRA.10.2.1.10.11_1. Centroid of nearest NUTS LAU region (16230) is 2958m.
# 2022-06-20 17:01:43,156 | INFO : No matching LAU region found for FRA.10.2.1.10.12_1. Centroid of nearest NUTS LAU region (16111) is 2519m.
# 2022-06-20 17:01:43,160 | INFO : No matching LAU region found for FRA.10.2.1.10.1_1. Centroid of nearest NUTS LAU region (16230) is 3971m.
# 2022-06-20 17:01:43,166 | INFO : No matching LAU region found for FRA.10.2.1.10.6_1. Centroid of nearest NUTS LAU region (16230) is 1637m.
# 2022-06-20 17:01:43,174 | INFO : No matching LAU region found for FRA.10.2.1.14.10_1. Centroid of nearest NUTS LAU region (16082) is 2817m.
# 2022-06-20 17:01:43,178 | INFO : No matching LAU region found for FRA.10.2.1.14.2_1. Centroid of nearest NUTS LAU region (16082) is 1486m.
# 2022-06-20 17:01:43,182 | INFO : No matching LAU region found for FRA.10.2.1.14.3_1. Centroid of nearest NUTS LAU region (16082) is 3039m.
# 2022-06-20 17:01:43,188 | INFO : No matching LAU region found for FRA.10.2.1.3.10_1. Centroid of nearest NUTS LAU region (16133) is 2213m.
# 2022-06-20 17:01:43,192 | INFO : No matching LAU region found for FRA.10.2.1.3.11_1. Centroid of nearest NUTS LAU region (16133) is 2230m.
# 2022-06-20 17:01:43,196 | INFO : No matching LAU region found for FRA.10.2.1.3.13_1. Centroid of nearest NUTS LAU region (16014) is 2524m.
# 2022-06-20 17:01:43,200 | INFO : No matching LAU region found for FRA.10.2.1.3.16_1. Centroid of nearest NUTS LAU region (16046) is 1477m.
# 2022-06-20 17:01:43,205 | INFO : No matching LAU region found for FRA.10.2.1.3.1_1. Centroid of nearest NUTS LAU region (16175) is 1372m.
# 2022-06-20 17:01:43,209 | INFO : No matching LAU region found for FRA.10.2.1.3.4_1. Centroid of nearest NUTS LAU region (16046) is 1657m.
# 2022-06-20 17:01:43,213 | INFO : No matching LAU region found for FRA.10.2.1.3.8_1. Centroid of nearest NUTS LAU region (16046) is 1927m.
# 2022-06-20 17:01:43,221 | INFO : No matching LAU region found for FRA.10.2.1.8.11_1. Centroid of nearest NUTS LAU region (16406) is 1527m.
# 2022-06-20 17:01:43,225 | INFO : No matching LAU region found for FRA.10.2.1.8.13_1. Centroid of nearest NUTS LAU region (16281) is 1221m.
# 2022-06-20 17:01:43,230 | INFO : No matching LAU region found for FRA.10.2.1.8.15_1. Centroid of nearest NUTS LAU region (16406) is 1885m.
# 2022-06-20 17:01:43,234 | INFO : No matching LAU region found for FRA.10.2.1.8.7_1. Centroid of nearest NUTS LAU region (16281) is 2754m.
# 2022-06-20 17:01:43,243 | INFO : No matching LAU region found for FRA.10.2.2.1.5_1. Centroid of nearest NUTS LAU region (16224) is 1625m.
# 2022-06-20 17:01:43,249 | INFO : No matching LAU region found for FRA.10.2.2.10.10_1. Centroid of nearest NUTS LAU region (16153) is 985m.
# 2022-06-20 17:01:43,253 | INFO : No matching LAU region found for FRA.10.2.2.10.7_1. Centroid of nearest NUTS LAU region (16153) is 1727m.
# 2022-06-20 17:01:43,257 | INFO : No matching LAU region found for FRA.10.2.2.2.11_1. Centroid of nearest NUTS LAU region (16224) is 973m.
# 2022-06-20 17:01:43,261 | INFO : No matching LAU region found for FRA.10.2.2.4.10_1. Centroid of nearest NUTS LAU region (16177) is 2771m.
# 2022-06-20 17:01:43,265 | INFO : No matching LAU region found for FRA.10.2.2.4.13_1. Centroid of nearest NUTS LAU region (16204) is 2704m.
# 2022-06-20 17:01:43,269 | INFO : No matching LAU region found for FRA.10.2.2.4.15_1. Centroid of nearest NUTS LAU region (16338) is 2061m.
# 2022-06-20 17:01:43,273 | INFO : No matching LAU region found for FRA.10.2.2.4.6_1. Centroid of nearest NUTS LAU region (16045) is 3337m.
# 2022-06-20 17:01:43,277 | INFO : No matching LAU region found for FRA.10.2.2.4.8_1. Centroid of nearest NUTS LAU region (16204) is 1242m.
# 2022-06-20 17:01:43,283 | INFO : No matching LAU region found for FRA.10.2.2.9.11_1. Centroid of nearest NUTS LAU region (16339) is 2228m.
# 2022-06-20 17:01:43,287 | INFO : No matching LAU region found for FRA.10.2.2.9.12_1. Centroid of nearest NUTS LAU region (16208) is 2526m.
# 2022-06-20 17:01:43,291 | INFO : No matching LAU region found for FRA.10.2.2.9.15_1. Centroid of nearest NUTS LAU region (17261) is 2923m.
# 2022-06-20 17:01:43,295 | INFO : No matching LAU region found for FRA.10.2.2.9.1_1. Centroid of nearest NUTS LAU region (16339) is 3056m.
# 2022-06-20 17:01:43,298 | INFO : No matching LAU region found for FRA.10.2.2.9.2_1. Centroid of nearest NUTS LAU region (16339) is 1486m.
# 2022-06-20 17:01:43,302 | INFO : No matching LAU region found for FRA.10.2.2.9.3_1. Centroid of nearest NUTS LAU region (16148) is 2304m.
# 2022-06-20 17:01:43,306 | INFO : No matching LAU region found for FRA.10.2.2.9.4_1. Centroid of nearest NUTS LAU region (16339) is 2598m.
# 2022-06-20 17:01:43,310 | INFO : No matching LAU region found for FRA.10.2.2.9.6_1. Centroid of nearest NUTS LAU region (16148) is 662m.
# 2022-06-20 17:01:43,313 | INFO : No matching LAU region found for FRA.10.2.2.9.7_1. Centroid of nearest NUTS LAU region (16207) is 4667m.
# 2022-06-20 17:01:43,317 | INFO : No matching LAU region found for FRA.10.2.3.1.15_1. Centroid of nearest NUTS LAU region (16005) is 861m.
# 2022-06-20 17:01:43,324 | INFO : No matching LAU region found for FRA.10.2.3.10.10_1. Centroid of nearest NUTS LAU region (16192) is 3090m.
# 2022-06-20 17:01:43,328 | INFO : No matching LAU region found for FRA.10.2.3.10.3_1. Centroid of nearest NUTS LAU region (16192) is 3882m.
# 2022-06-20 17:01:43,336 | INFO : No matching LAU region found for FRA.10.2.3.10.7_1. Centroid of nearest NUTS LAU region (16096) is 3032m.
# 2022-06-20 17:01:43,340 | INFO : No matching LAU region found for FRA.10.2.3.11.18_1. Centroid of nearest NUTS LAU region (16110) is 1624m.
# 2022-06-20 17:01:43,352 | INFO : No matching LAU region found for FRA.10.2.3.2.11_1. Centroid of nearest NUTS LAU region (16183) is 4168m.
# 2022-06-20 17:01:43,356 | INFO : No matching LAU region found for FRA.10.2.3.2.7_1. Centroid of nearest NUTS LAU region (16134) is 3078m.
# 2022-06-20 17:01:43,365 | INFO : No matching LAU region found for FRA.10.2.3.5.9_1. Centroid of nearest NUTS LAU region (16106) is 2849m.
# 2022-06-20 17:01:43,371 | INFO : No matching LAU region found for FRA.10.2.3.7.18_1. Centroid of nearest NUTS LAU region (16300) is 1796m.
# 2022-06-20 17:01:43,376 | INFO : No matching LAU region found for FRA.10.2.3.7.19_1. Centroid of nearest NUTS LAU region (16300) is 1684m.
# 2022-06-20 17:01:43,380 | INFO : No matching LAU region found for FRA.10.2.3.7.1_1. Centroid of nearest NUTS LAU region (16023) is 1265m.
# 2022-06-20 17:01:43,383 | INFO : No matching LAU region found for FRA.10.2.3.7.23_1. Centroid of nearest NUTS LAU region (16300) is 2664m.
# 2022-06-20 17:01:43,388 | INFO : No matching LAU region found for FRA.10.2.3.7.2_1. Centroid of nearest NUTS LAU region (16238) is 1335m.
# 2022-06-20 17:01:43,391 | INFO : No matching LAU region found for FRA.10.2.3.7.5_1. Centroid of nearest NUTS LAU region (16023) is 1247m.
# ...
# 2022-06-20 17:02:08,809 | INFO : No matching LAU region found for NLD.14.83_1. Centroid of nearest NUTS LAU region (GM1525) is 1920m.
# 2022-06-20 17:02:08,812 | INFO : No matching LAU region found for NLD.14.85_1. Centroid of nearest NUTS LAU region (GM0603) is 4250m.
# 2022-06-20 17:02:08,816 | INFO : No matching LAU region found for NLD.14.87_1. Centroid of nearest NUTS LAU region (GM1961) is 2724m.
# 2022-06-20 17:02:08,820 | INFO : No matching LAU region found for NLD.14.88_1. Centroid of nearest NUTS LAU region (GM1892) is 2693m.
# 2022-06-20 17:02:08,825 | INFO : No matching LAU region found for NLD.14.9_1. Centroid of nearest NUTS LAU region (GM1931) is 1869m.
# 2022-06-20 17:02:08,829 | INFO : No matching LAU region found for NLD.3.12_1. Centroid of nearest NUTS LAU region (GM1949) is 6892m.
# 2022-06-20 17:02:08,833 | INFO : No matching LAU region found for NLD.3.13_1. Centroid of nearest NUTS LAU region (GM0059) is 9498m.
# 2022-06-20 17:02:08,837 | INFO : No matching LAU region found for NLD.3.15_1. Centroid of nearest NUTS LAU region (GM0080) is 10035m.
# 2022-06-20 17:02:08,840 | INFO : No matching LAU region found for NLD.3.16_1. Centroid of nearest NUTS LAU region (GM1940) is 7312m.
# 2022-06-20 17:02:08,844 | INFO : No matching LAU region found for NLD.3.17_1. Centroid of nearest NUTS LAU region (GM0080) is 10518m.
# 2022-06-20 17:02:08,847 | INFO : No matching LAU region found for NLD.3.18_1. Centroid of nearest NUTS LAU region (GM1949) is 4767m.
# 2022-06-20 17:02:08,851 | INFO : No matching LAU region found for NLD.3.19_1. Centroid of nearest NUTS LAU region (GM1900) is 7861m.
# 2022-06-20 17:02:08,855 | INFO : No matching LAU region found for NLD.3.23_1. Centroid of nearest NUTS LAU region (GM1940) is 11060m.
# 2022-06-20 17:02:08,858 | INFO : No matching LAU region found for NLD.3.25_1. Centroid of nearest NUTS LAU region (GM1900) is 15449m.
# 2022-06-20 17:02:08,862 | INFO : No matching LAU region found for NLD.3.30_1. Centroid of nearest NUTS LAU region (GM1900) is 8389m.
# 2022-06-20 17:02:08,866 | INFO : No matching LAU region found for NLD.3.31_1. Centroid of nearest NUTS LAU region (GM1900) is 10347m.
# 2022-06-20 17:02:08,870 | INFO : No matching LAU region found for NLD.3.3_1. Centroid of nearest NUTS LAU region (GM0080) is 9438m.
# 2022-06-20 17:02:08,874 | INFO : No matching LAU region found for NLD.3.4_1. Centroid of nearest NUTS LAU region (GM1900) is 8637m.
# 2022-06-20 17:02:08,880 | INFO : No matching LAU region found for NLD.3.6_1. Centroid of nearest NUTS LAU region (GM1970) is 3489m.
# 2022-06-20 17:02:08,883 | INFO : No matching LAU region found for NLD.3.7_1. Centroid of nearest NUTS LAU region (GM1891) is 11247m.
# 2022-06-20 17:02:08,887 | INFO : No matching LAU region found for NLD.3.8_1. Centroid of nearest NUTS LAU region (GM1949) is 5743m.
# 2022-06-20 17:02:08,890 | INFO : No matching LAU region found for NLD.3.9_1. Centroid of nearest NUTS LAU region (GM1940) is 7385m.
# 2022-06-20 17:02:08,893 | INFO : No matching LAU region found for NLD.4.12_1. Centroid of nearest NUTS LAU region (GM0299) is 4581m.
# 2022-06-20 17:02:08,896 | INFO : No matching LAU region found for NLD.4.13_1. Centroid of nearest NUTS LAU region (GM0197) is 5265m.
# 2022-06-20 17:02:08,900 | INFO : No matching LAU region found for NLD.4.19_1. Centroid of nearest NUTS LAU region (GM1859) is 5410m.
# 2022-06-20 17:02:08,904 | INFO : No matching LAU region found for NLD.4.23_1. Centroid of nearest NUTS LAU region (GM1960) is 3211m.
# 2022-06-20 17:02:08,907 | INFO : No matching LAU region found for NLD.4.24_1. Centroid of nearest NUTS LAU region (GM1509) is 3483m.
# 2022-06-20 17:02:08,910 | INFO : No matching LAU region found for NLD.4.25_1. Centroid of nearest NUTS LAU region (GM0262) is 5629m.
# 2022-06-20 17:02:08,914 | INFO : No matching LAU region found for NLD.4.26_1. Centroid of nearest NUTS LAU region (GM1586) is 5232m.
# 2022-06-20 17:02:08,917 | INFO : No matching LAU region found for NLD.4.27_1. Centroid of nearest NUTS LAU region (GM1945) is 3817m.
# 2022-06-20 17:02:08,921 | INFO : No matching LAU region found for NLD.4.2_1. Centroid of nearest NUTS LAU region (GM0221) is 5143m.
# 2022-06-20 17:02:08,927 | INFO : No matching LAU region found for NLD.4.31_1. Centroid of nearest NUTS LAU region (GM1876) is 2599m.
# 2022-06-20 17:02:08,931 | INFO : No matching LAU region found for NLD.4.33_1. Centroid of nearest NUTS LAU region (GM0222) is 6532m.
# 2022-06-20 17:02:08,936 | INFO : No matching LAU region found for NLD.4.35_1. Centroid of nearest NUTS LAU region (GM1586) is 1257m.
# 2022-06-20 17:02:08,940 | INFO : No matching LAU region found for NLD.4.36_1. Centroid of nearest NUTS LAU region (GM0297) is 7664m.
# 2022-06-20 17:02:08,943 | INFO : No matching LAU region found for NLD.4.40_1. Centroid of nearest NUTS LAU region (GM0299) is 7502m.
# 2022-06-20 17:02:08,947 | INFO : No matching LAU region found for NLD.4.41_1. Centroid of nearest NUTS LAU region (GM1859) is 6336m.
# 2022-06-20 17:02:08,951 | INFO : No matching LAU region found for NLD.4.42_1. Centroid of nearest NUTS LAU region (GM1960) is 6135m.
# 2022-06-20 17:02:08,954 | INFO : No matching LAU region found for NLD.4.51_1. Centroid of nearest NUTS LAU region (GM0299) is 4973m.
# 2022-06-20 17:02:08,959 | INFO : No matching LAU region found for NLD.4.53_1. Centroid of nearest NUTS LAU region (GM1859) is 7754m.
# 2022-06-20 17:02:08,964 | INFO : No matching LAU region found for NLD.4.55_1. Centroid of nearest NUTS LAU region (GM0221) is 6366m.
# 2022-06-20 17:02:08,970 | INFO : No matching LAU region found for NLD.4.57_1. Centroid of nearest NUTS LAU region (GM1945) is 3281m.
# 2022-06-20 17:02:08,975 | INFO : No matching LAU region found for NLD.4.59_1. Centroid of nearest NUTS LAU region (GM1876) is 6648m.
# 2022-06-20 17:02:08,979 | INFO : No matching LAU region found for NLD.4.61_1. Centroid of nearest NUTS LAU region (GM0301) is 3312m.
# 2022-06-20 17:02:08,983 | INFO : No matching LAU region found for NLD.4.62_1. Centroid of nearest NUTS LAU region (GM1955) is 5131m.
# 2022-06-20 17:02:08,986 | INFO : No matching LAU region found for NLD.4.67_1. Centroid of nearest NUTS LAU region (GM1509) is 3905m.
# 2022-06-20 17:02:08,990 | INFO : No matching LAU region found for NLD.4.69_1. Centroid of nearest NUTS LAU region (GM1876) is 7440m.
# 2022-06-20 17:02:08,995 | INFO : No matching LAU region found for NLD.4.6_1. Centroid of nearest NUTS LAU region (GM1955) is 2886m.
# 2022-06-20 17:02:08,999 | INFO : No matching LAU region found for NLD.4.8_1. Centroid of nearest NUTS LAU region (GM1859) is 3984m.
# 2022-06-20 17:02:09,002 | INFO : No matching LAU region found for NLD.5.10_1. Centroid of nearest NUTS LAU region (GM1952) is 6363m.
# 2022-06-20 17:02:09,007 | INFO : No matching LAU region found for NLD.5.11_1. Centroid of nearest NUTS LAU region (GM1969) is 6731m.
# 2022-06-20 17:02:09,011 | INFO : No matching LAU region found for NLD.5.13_1. Centroid of nearest NUTS LAU region (GM1969) is 8554m.
# 2022-06-20 17:02:09,015 | INFO : No matching LAU region found for NLD.5.14_1. Centroid of nearest NUTS LAU region (GM1952) is 6281m.
# 2022-06-20 17:02:09,019 | INFO : No matching LAU region found for NLD.5.16_1. Centroid of nearest NUTS LAU region (GM1895) is 5833m.
# 2022-06-20 17:02:09,024 | INFO : No matching LAU region found for NLD.5.17_1. Centroid of nearest NUTS LAU region (GM1895) is 3648m.
# 2022-06-20 17:02:09,029 | INFO : No matching LAU region found for NLD.5.18_1. Centroid of nearest NUTS LAU region (GM1952) is 4576m.
# 2022-06-20 17:02:09,033 | INFO : No matching LAU region found for NLD.5.20_1. Centroid of nearest NUTS LAU region (GM0024) is 7152m.
# 2022-06-20 17:02:09,037 | INFO : No matching LAU region found for NLD.5.22_1. Centroid of nearest NUTS LAU region (GM1950) is 6535m.
# 2022-06-20 17:02:09,041 | INFO : No matching LAU region found for NLD.5.23_1. Centroid of nearest NUTS LAU region (GM1895) is 5903m.
# 2022-06-20 17:02:09,045 | INFO : No matching LAU region found for NLD.5.24_1. Centroid of nearest NUTS LAU region (GM1966) is 5620m.
# 2022-06-20 17:02:09,049 | INFO : No matching LAU region found for NLD.5.25_1. Centroid of nearest NUTS LAU region (GM1969) is 6693m.
# 2022-06-20 17:02:09,052 | INFO : No matching LAU region found for NLD.5.2_1. Centroid of nearest NUTS LAU region (GM0014) is 8504m.
# 2022-06-20 17:02:09,056 | INFO : No matching LAU region found for NLD.5.3_1. Centroid of nearest NUTS LAU region (GM1950) is 9010m.
# 2022-06-20 17:02:09,060 | INFO : No matching LAU region found for NLD.5.4_1. Centroid of nearest NUTS LAU region (GM1966) is 10930m.
# 2022-06-20 17:02:09,064 | INFO : No matching LAU region found for NLD.5.6_1. Centroid of nearest NUTS LAU region (GM0024) is 9205m.
# 2022-06-20 17:02:09,068 | INFO : No matching LAU region found for NLD.5.8_1. Centroid of nearest NUTS LAU region (GM1969) is 4016m.
# 2022-06-20 17:02:09,073 | INFO : No matching LAU region found for NLD.5.9_1. Centroid of nearest NUTS LAU region (GM1730) is 6813m.
# 2022-06-20 17:02:09,077 | INFO : No matching LAU region found for NLD.6.1_1. Centroid of nearest NUTS LAU region (GM0532) is 7306m.
# 2022-06-20 17:02:09,080 | INFO : No matching LAU region found for NLD.7.11_1. Centroid of nearest NUTS LAU region (GM1640) is 5000m.
# 2022-06-20 17:02:09,084 | INFO : No matching LAU region found for NLD.7.12_1. Centroid of nearest NUTS LAU region (GM1641) is 3171m.
# 2022-06-20 17:02:09,087 | INFO : No matching LAU region found for NLD.7.14_1. Centroid of nearest NUTS LAU region (GM1894) is 1386m.
# 2022-06-20 17:02:09,091 | INFO : No matching LAU region found for NLD.7.15_1. Centroid of nearest NUTS LAU region (GM1640) is 1236m.
# 2022-06-20 17:02:09,095 | INFO : No matching LAU region found for NLD.7.17_1. Centroid of nearest NUTS LAU region (GM1641) is 6663m.
# 2022-06-20 17:02:09,098 | INFO : No matching LAU region found for NLD.7.19_1. Centroid of nearest NUTS LAU region (GM0889) is 3471m.
# 2022-06-20 17:02:09,102 | INFO : No matching LAU region found for NLD.7.1_1. Centroid of nearest NUTS LAU region (GM1669) is 3329m.
# 2022-06-20 17:02:09,106 | INFO : No matching LAU region found for NLD.7.21_1. Centroid of nearest NUTS LAU region (GM1641) is 2469m.
# 2022-06-20 17:02:09,109 | INFO : No matching LAU region found for NLD.7.22_1. Centroid of nearest NUTS LAU region (GM1894) is 5598m.
# 2022-06-20 17:02:09,113 | INFO : No matching LAU region found for NLD.7.24_1. Centroid of nearest NUTS LAU region (GM1903) is 2194m.
# 2022-06-20 17:02:09,116 | INFO : No matching LAU region found for NLD.7.25_1. Centroid of nearest NUTS LAU region (GM0893) is 8217m.
# 2022-06-20 17:02:09,121 | INFO : No matching LAU region found for NLD.7.27_1. Centroid of nearest NUTS LAU region (GM1894) is 7544m.
# 2022-06-20 17:02:09,125 | INFO : No matching LAU region found for NLD.7.2_1. Centroid of nearest NUTS LAU region (GM0983) is 6829m.
# 2022-06-20 17:02:09,129 | INFO : No matching LAU region found for NLD.7.30_1. Centroid of nearest NUTS LAU region (GM1954) is 3765m.
# 2022-06-20 17:02:09,132 | INFO : No matching LAU region found for NLD.7.31_1. Centroid of nearest NUTS LAU region (GM0899) is 3138m.
# 2022-06-20 17:02:09,136 | INFO : No matching LAU region found for NLD.7.34_1. Centroid of nearest NUTS LAU region (GM1640) is 6511m.
# 2022-06-20 17:02:09,140 | INFO : No matching LAU region found for NLD.7.35_1. Centroid of nearest NUTS LAU region (GM1954) is 1785m.
# 2022-06-20 17:02:09,143 | INFO : No matching LAU region found for NLD.7.36_1. Centroid of nearest NUTS LAU region (GM1507) is 5124m.
# 2022-06-20 17:02:09,147 | INFO : No matching LAU region found for NLD.7.40_1. Centroid of nearest NUTS LAU region (GM0957) is 3817m.
# 2022-06-20 17:02:09,151 | INFO : No matching LAU region found for NLD.7.41_1. Centroid of nearest NUTS LAU region (GM1641) is 1858m.
# 2022-06-20 17:02:09,157 | INFO : No matching LAU region found for NLD.7.8_1. Centroid of nearest NUTS LAU region (GM1903) is 3626m.
# 2022-06-20 17:02:09,160 | INFO : No matching LAU region found for NLD.8.24_1. Centroid of nearest NUTS LAU region (GM1771) is 2008m.
# 2022-06-20 17:02:09,164 | INFO : No matching LAU region found for NLD.8.2_1. Centroid of nearest NUTS LAU region (GM0867) is 7242m.
# 2022-06-20 17:02:09,168 | INFO : No matching LAU region found for NLD.8.37_1. Centroid of nearest NUTS LAU region (GM0828) is 5826m.
# 2022-06-20 17:02:09,171 | INFO : No matching LAU region found for NLD.8.39_1. Centroid of nearest NUTS LAU region (GM1721) is 6735m.
# 2022-06-20 17:02:09,175 | INFO : No matching LAU region found for NLD.8.40_1. Centroid of nearest NUTS LAU region (GM1771) is 2338m.
# 2022-06-20 17:02:09,182 | INFO : No matching LAU region found for NLD.8.51_1. Centroid of nearest NUTS LAU region (GM1948) is 5577m.
# 2022-06-20 17:02:09,185 | INFO : No matching LAU region found for NLD.8.53_1. Centroid of nearest NUTS LAU region (GM1948) is 3727m.
# 2022-06-20 17:02:09,189 | INFO : No matching LAU region found for NLD.8.61_1. Centroid of nearest NUTS LAU region (GM1948) is 5284m.
# 2022-06-20 17:02:09,194 | INFO : No matching LAU region found for NLD.8.66_1. Centroid of nearest NUTS LAU region (GM1959) is 4337m.
# 2022-06-20 17:02:09,198 | INFO : No matching LAU region found for NLD.8.68_1. Centroid of nearest NUTS LAU region (GM1959) is 4144m.
# 2022-06-20 17:02:09,202 | INFO : No matching LAU region found for NLD.9.13_1. Centroid of nearest NUTS LAU region (GM0402) is 5253m.
# 2022-06-20 17:02:09,206 | INFO : No matching LAU region found for NLD.9.20_1. Centroid of nearest NUTS LAU region (GM0361) is 5721m.
# 2022-06-20 17:02:09,211 | INFO : No matching LAU region found for NLD.9.22_1. Centroid of nearest NUTS LAU region (GM0392) is 5056m.
# 2022-06-20 17:02:09,215 | INFO : No matching LAU region found for NLD.9.24_1. Centroid of nearest NUTS LAU region (GM0416) is 5093m.
# 2022-06-20 17:02:09,219 | INFO : No matching LAU region found for NLD.9.36_1. Centroid of nearest NUTS LAU region (GM0457) is 2886m.
# 2022-06-20 17:02:09,223 | INFO : No matching LAU region found for NLD.9.37_1. Centroid of nearest NUTS LAU region (GM1942) is 3148m.
# 2022-06-20 17:02:09,227 | INFO : No matching LAU region found for NLD.9.38_1. Centroid of nearest NUTS LAU region (GM0432) is 6871m.
# 2022-06-20 17:02:09,230 | INFO : No matching LAU region found for NLD.9.39_1. Centroid of nearest NUTS LAU region (GM0432) is 7169m.
# 2022-06-20 17:02:09,234 | INFO : No matching LAU region found for NLD.9.40_1. Centroid of nearest NUTS LAU region (GM1598) is 3964m.
# 2022-06-20 17:02:09,238 | INFO : No matching LAU region found for NLD.9.46_1. Centroid of nearest NUTS LAU region (GM0361) is 1595m.
# 2022-06-20 17:02:09,242 | INFO : No matching LAU region found for NLD.9.52_1. Centroid of nearest NUTS LAU region (GM0498) is 691m.
# 2022-06-20 17:02:09,246 | INFO : No matching LAU region found for NLD.9.55_1. Centroid of nearest NUTS LAU region (GM0420) is 5850m.
# 2022-06-20 17:02:09,250 | INFO : No matching LAU region found for NLD.9.56_1. Centroid of nearest NUTS LAU region (GM1598) is 1512m.
# 2022-06-20 17:02:09,255 | INFO : No matching LAU region found for NLD.9.57_1. Centroid of nearest NUTS LAU region (GM1911) is 6752m.
# 2022-06-20 17:02:09,259 | INFO : No matching LAU region found for NLD.9.58_1. Centroid of nearest NUTS LAU region (GM1911) is 2696m.
# 2022-06-20 17:02:09,263 | INFO : No matching LAU region found for NLD.9.5_1. Centroid of nearest NUTS LAU region (GM0532) is 3840m.
# 2022-06-20 17:02:09,266 | INFO : No matching LAU region found for NLD.9.60_1. Centroid of nearest NUTS LAU region (GM0405) is 6613m.
# 2022-06-20 17:02:09,271 | INFO : No matching LAU region found for NLD.9.64_1. Centroid of nearest NUTS LAU region (GM0385) is 1943m.
# 2022-06-20 17:02:09,275 | INFO : No matching LAU region found for NLD.9.65_1. Centroid of nearest NUTS LAU region (GM0441) is 3133m.
# 2022-06-20 17:02:09,282 | INFO : No matching LAU region found for NLD.9.6_1. Centroid of nearest NUTS LAU region (GM1911) is 9262m.
# 2022-06-20 17:02:09,287 | INFO : No matching LAU region found for NLD.9.8_1. Centroid of nearest NUTS LAU region (GM0397) is 2850m.

# %%
gadm_spain_lau.to_csv(os.path.join('..', 'metadata', 'ES-LAU-GADM-mapping.csv'), index=False)
gadm_netherlands_lau.to_csv(os.path.join('..', 'metadata', 'NL-LAU-GADM-mapping.csv'), index=False)
gadm_5_france_lau.to_csv(os.path.join('..', 'metadata', 'FR-LAU-GADM-mapping.csv'), index=False)
# gadm_spain_lau['DEGURBA'] 
# gadm_5_france_lau['DEGURBA']
# gadm_netherlands_lau['DEGURBA']

# %%
gadm_5_france_lau = pd.read_csv(os.path.join('..', 'metadata', 'FR-LAU-GADM-5-mapping.csv'))

# %% [markdown]
# #### 1.3. Special case France: aggregating GADM lvl 5 / LAU regions to GADM lvl 4 regions

# %% [markdown]
# Aggregation logic: choosing most common DEGURBA in region (for ties choose higher DEGURBA)

# %%
## proper aggregation using unique GID_4 instead of NAME_4
region_types = gadm_5_france_lau.groupby('GID_4')['DEGURBA'].agg(lambda x: pd.Series.mode(x).max()).to_dict()
gadm_france_lau = gadm_france.copy()
gadm_france_lau['DEGURBA'] = gadm_france['GID_4'].map(region_types)

# current workaround because fragmented city mappings are based on NAME not GID
# fragments_to_new_name = invert_fragmented_cities_mapping(fragmented_cities_lvl4['France'] + fragmented_cities_lvl3['France'])
# gadm_5_france_lau['NAME_4'] = gadm_5_france_lau['NAME_4'].map(fragments_to_new_name).fillna(gadm_5_france_lau['NAME_4'])

# region_types = gadm_5_france_lau.groupby('NAME_4')['DEGURBA'].agg(lambda x: pd.Series.mode(x).max()).to_dict()
# gadm_france_lau = gadm_france.copy()
# gadm_france_lau['DEGURBA'] = gadm_france['NAME_4'].map(region_types)

# if population data would become available for France with new LAU data release
# region_population = gadm_5_france_lau.groupby('GID_4')['POPULATION'].sum().to_dict()
# gadm_france['population'] = gadm_france['GID_4'].map(region_population)

gadm_france_lau.to_csv(os.path.join('..', 'metadata', 'FR-LAU-GADM-mapping.csv'), index=False)

# %% [markdown]
# #### 1.4. Validation

# %%
for country, m in {'spain': gadm_spain_lau, 'netherlands': gadm_netherlands_lau, 'france': gadm_5_france_lau}.items():
    m_avg = m.head(50)
    m_bad = m.sort_values('centroid_distance', ascending=False).head(10)
    print(f"{country}: share of assigments with distance > 1000m: {len(m[m['centroid_distance'] > 1000]) / len(m) * 100:.1f}%")
    visualize_region_matching(m_avg)
    visualize_region_matching(m_bad)
# Out:
# spain: share of assigments with distance > 1000m: 1.9%
# netherlands: share of assigments with distance > 1000m: 35.6%
# france: share of assigments with distance > 1000m: 6.0%

# %%
_, ax = plt.subplots(1, 1)
lau_fr_ambiguous[lau_fr_ambiguous['LAU_ID'].isin(['01015', '01061', '73028'])].plot(ax=ax, column='LAU_NAME', cmap='tab20', legend=True)
gadm_5_france_ambiguous[gadm_5_france_ambiguous['GID_5'] == 'FRA.1.1.1.2.6_1'].to_crs(3035).plot(ax=ax, color='red', alpha=0.5)

# lau_fr[lau_fr['LAU_ID'].isin(['08103'])].plot(ax=ax, column='LAU_NAME', cmap='tab20', legend=True)
# gadm_5_france_ambiguous[gadm_5_france_ambiguous['GID_5'] == 'FRA.6.1.4.1.2_1'].to_crs(3035).plot(ax=ax, color='red', alpha=0.5)
# Out:
# 2022-05-09 09:23:10,766 | WARNING : The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
# <AxesSubplot:>

# %% [markdown]
# ### 2. Grouping of fragmented cities (France)

# %%
import json

with open(os.path.join('..', 'data', 'fragmented-cities-candidates-regex-level-3.json'), 'r') as file:
    fragmented_cities_lvl3 = json.load(file)

with open(os.path.join('..', 'data', 'fragmented-cities-candidates-regex-level-4.json'), 'r') as file:
    fragmented_cities_lvl4 = json.load(file)

# %%
def invert_fragmented_cities_mapping(l):
    new_dic = {}
    for region in l:
        new_name = region[0]
        fragments = region[1]
        for x in fragments:
            new_dic[x] = new_name
    return new_dic

# %%
fragments_to_new_name = invert_fragmented_cities_mapping(fragmented_cities_lvl4['France'] + fragmented_cities_lvl3['France'])
overview_france['city'] = overview_france['city'].map(fragments_to_new_name).fillna(overview_france['city'])
grouped_overview_france = overview_france.groupby('city')[['bldgs_n_tot', 'a_tot']].sum()
grouped_overview_france = pd.concat([grouped_overview_france, overview_france.groupby('city')['age_p', 'age_p_1901_1950', 'age_p_1951_2000', 'age_p_2001_2022', 'height_mean'].mean()], axis=1)
grouped_overview_france.reset_index(inplace=True)
# Out:
# 2022-05-09 10:58:21,270 | WARNING : Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# ### 3. Handling of duplicate city names (Spain)

# %%
# logic from https://github.com/ai4up/eubucco/blob/main/eubucco/preproc/db_set_up.py#L253-L262

# add region_name to city name where we have duplicates
g_d = gadm_spain_lau[gadm_spain_lau.duplicated(subset=['NAME_4'])]
g_d['NAME_4'] = g_d['NAME_4'] + ' (' + g_d['NAME_1'] + ')'

# in cases where we have more than one duplicated; add orignal index as str behind dupl
g_d_2 = g_d[g_d.duplicated(subset=['NAME_4'])]
g_d = g_d.drop(g_d_2.index)

g_d_2['NAME_4'] = g_d_2['NAME_4'] + '_' + g_d_2.index.map(str)
g_d = g_d.append(g_d_2)

gadm_spain_lau = gadm_spain_lau.drop(g_d.index).append(g_d)
# Out:
# 2022-06-20 17:18:53,498 | WARNING :
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2022-06-20 17:18:53,519 | WARNING : The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2022-06-20 17:18:53,541 | WARNING : The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# ### 4. Calculation of additional selection metrics

# %%
country_dfs = {}
country_infos = [
    ('netherlands', gadm_netherlands_lau, overview_netherlands),
    ('france', gadm_france_lau, grouped_overview_france),
    ('spain', gadm_spain_lau, overview_spain),
]

for country, gadm, overview in country_infos:
    gadm_level = gadm_info[gadm_info['country_name'] == country]['level_city'].values[0]

    df = gadm[[f'NAME_{gadm_level}', f'NAME_{gadm_level - 1}', 'DEGURBA', 'geometry']].merge(overview, left_on=f'NAME_{gadm_level}', right_on='city', how='inner')

    df['a_3d'] = df['height_mean'] * df['a_tot']
    df['bldgs_per_km2'] = df['bldgs_n_tot'] / df['geometry'].to_crs(3035).area * 1000**2
    df['build_up_area'] = df['a_tot'] / df['geometry'].to_crs(3035).area
    df['build_up_area_3d'] = df['a_3d'] / df['geometry'].to_crs(3035).area
    df[['age_p_1901_1950', 'age_p_1951_2000', 'age_p_2001_2022']] = df[['age_p_1901_1950', 'age_p_1951_2000', 'age_p_2001_2022']].div(df['age_p'], axis=0)
    country_dfs[country] = df

# %% [markdown]
# ## Selection

# %% [markdown]
# ### 1. Inspection

# %%
country_dfs['france']['DEGURBA'].value_counts()
# Out:
# 3.0    2706
# 2.0     460
# 1.0     213
# Name: DEGURBA, dtype: int64

# %%
# cities have fewer buildings / building to inhabitants ratio is lower (maybe because of more coarse building block information & different gadm boundaries)
# * have different rural, town, urban criterias for Spain
# * use inhabitant information instead of buildings to differentiate between city types
# * just use n largest cities per country
# country_dfs['netherlands'].sort_values(by='bldgs_n_tot', ascending=False)[['city', 'age_p', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area', 'a_tot']].head(50)
country_dfs['netherlands'][country_dfs['netherlands']['city'].isin(['Maastricht', 'Almelo', 'Ede'])].sort_values(by='bldgs_n_tot', ascending=False)[['city', 'age_p', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area', 'a_tot']]
# country_dfs['france'][country_dfs['france']['city'].isin(['Aix-en-Provence', 'Rennes', 'Limoges'])].sort_values(by='bldgs_n_tot', ascending=False)[['city', 'age_p', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area', 'a_tot']]
# country_dfs['spain'][country_dfs['spain']['city'].isin(['Valencia', 'Cartagena', 'Vigo', 'Zaragoza', 'Alicante', 'Oviedo', 'Málaga', 'Bilbao', 'Palma de Mallorca'])].sort_values(by='bldgs_n_tot', ascending=False)[['city', 'age_p', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/D062794/workspace/ufo-prediction/notebooks/city_selection.ipynb Cell 14' in <module>
#       <a href='vscode-notebook-cell:/Users/D062794/workspace/ufo-prediction/notebooks/city_selection.ipynb#ch0000013?line=0'>1</a> # cities have fewer buildings / building to inhabitants ratio is lower (maybe because of more coarse building block information & different gadm boundaries)
#       <a href='vscode-notebook-cell:/Users/D062794/workspace/ufo-prediction/notebooks/city_selection.ipynb#ch0000013?line=1'>2</a> # * have different rural, town, urban criterias for Spain
#       <a href='vscode-notebook-cell:/Users/D062794/workspace/ufo-prediction/notebooks/city_selection.ipynb#ch0000013?line=2'>3</a> # * use inhabitant information instead of buildings to differentiate between city types
#       <a href='vscode-notebook-cell:/Users/D062794/workspace/ufo-prediction/notebooks/city_selection.ipynb#ch0000013?line=3'>4</a> # * just use n largest cities per country
#       <a href='vscode-notebook-cell:/Users/D062794/workspace/ufo-prediction/notebooks/city_selection.ipynb#ch0000013?line=4'>5</a> # country_dfs['netherlands'].sort_values(by='bldgs_n_tot', ascending=False)[['city', 'age_p', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area', 'a_tot']].head(50)
# ----> <a href='vscode-notebook-cell:/Users/D062794/workspace/ufo-prediction/notebooks/city_selection.ipynb#ch0000013?line=5'>6</a> country_dfs['netherlands'][country_dfs['netherlands']['city'].isin(['Maastricht', 'Almelo', 'Ede'])].sort_values(by='bldgs_n_tot', ascending=False)[['city', 'age_p', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area', 'a_tot']]
#
# NameError: name 'country_dfs' is not defined

# %%
towns(country_dfs['spain']).sort_values(by='build_up_area', ascending=False)[['city', 'DEGURBA', 'a_3d', 'age_p', 'a_tot', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area', 'height_mean', 'build_up_area_3d']].head(10)
# Out:
#              city  DEGURBA          a_3d  age_p        a_tot  bldgs_n_tot  \
# 5877    Emperador      2.0  6.514620e+04    1.0     9364.123         46.0
# 5901  Beniparrell      2.0  4.151645e+06    1.0   878840.975       1158.0
# 5918   Benirredrà      2.0  3.899088e+05    1.0    63081.829        398.0
# 8230     Barañain      2.0  3.189699e+06    0.0   240351.044        175.0
# 7472   Rafelbuñol      2.0  3.242501e+06    1.0   599796.658       2492.0
# 7462     L'Eliana      2.0  4.658844e+06    1.0  1254063.019       9096.0
# 5972   Almussafes      2.0  8.837991e+06    1.0  1508447.061       2145.0
# 5792     Almazora      2.0  2.253938e+07    1.0  4534173.427       9824.0
# 5917      Beniflá      2.0  4.015334e+05    1.0    83670.220        206.0
# 1406      Reinosa      2.0  4.175792e+06    1.0   584926.748       1619.0
#
#       bldgs_per_km2  build_up_area  height_mean  build_up_area_3d
# 5877    1999.792201       0.407093        6.957          2.832149
# 5901     306.730383       0.232787        4.724          1.099685
# 5918    1104.335226       0.175034        6.181          1.081884
# 8230     124.616550       0.171153       13.271          2.271367
# 7472     610.512173       0.146943        5.406          0.794376
# 7462    1033.306949       0.142462        3.715          0.529245
# 5972     198.803237       0.139806        5.859          0.819124
# 5792     297.887106       0.137487        4.971          0.683448
# 5917     334.869280       0.136013        4.799          0.652724
# 1406     374.064444       0.135145        7.139          0.964803

# %%
rural_area(country_dfs['spain']).sort_values(by='bldgs_per_km2', ascending=False)[['city', 'age_p', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area']].head(10)
# Out:
#                           city  age_p  bldgs_n_tot  bldgs_per_km2  \
# 1357                   Maleján   0.99        168.0    5492.373429
# 7491       La Aldea del Obispo   1.00        602.0    1815.811882
# 7737   El Puente del Arzobispo   0.99       1147.0    1115.135712
# 5748                     Geldo   1.00        500.0     970.415946
# 4751  Castellfollit de la Roca   1.00        419.0     655.816987
# 7540          A Illa de Arousa   0.99       2430.0     380.185520
# 659    Carrión de los Céspedes   1.00       2216.0     364.362039
# 5855     Llocnou d'En Fenollet   1.00        519.0     362.255458
# 4864                     Breda   1.00       1763.0     346.729071
# 4868                 Hostalric   1.00       1124.0     328.174565
#
#       build_up_area
# 1357       0.416983
# 7491       0.149351
# 7737       0.140588
# 5748       0.068301
# 4751       0.089761
# 7540       0.044974
# 659        0.042932
# 5855       0.046513
# 4864       0.058739
# 4868       0.087859

# %%
towns(country_dfs['france']).sort_values(by='bldgs_n_tot', ascending=False)[['city', 'age_p', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area']].head(10)
# Out:
#                     city     age_p  bldgs_n_tot  bldgs_per_km2  build_up_area
# 2491            Léguevin  0.370000      49985.0     380.588926       0.031374
# 2639           Perpignan  0.560000      49584.0     718.442325       0.108409
# 887             Chartres  0.545000      49248.0     130.743933       0.016466
# 2116  Castelnau-de-Médoc  0.460000      49195.0      51.041416       0.005028
# 2144             Limoges  0.610000      48842.0     600.196426       0.093319
# 1139         Bischwiller  0.490000      48643.0     270.102403       0.022232
# 2351            Narbonne  0.483333      48007.0     164.940975       0.017576
# 1484              Seclin  0.550000      47961.0     501.861421       0.063663
# 2468               Muret  0.400000      47915.0     283.072550       0.027908
# 1450             Cambrai  0.576667      47761.0     274.255922       0.031340

# %% [markdown]
# ### 2. Criterias for geographic & urban typology diversity

# %%
import warnings
warnings.filterwarnings('ignore', message='Geometry is in a geographic CRS')

centroid_france_x = 2.2137
centroid_france_y = 46.2276
centroid_netherlands_x = 5.2913
centroid_netherlands_y = 52.1326
centroid_spain_x = -3.7037
centroid_spain_y = 40.4165


centroid_coordinates = {
    'france': (centroid_france_x, centroid_france_y),
    'netherlands': (centroid_netherlands_x, centroid_netherlands_y),
    'spain': (centroid_spain_x, centroid_spain_y),
}


def north_eastern(df, centroid_x, centroid_y):
    city_centroids = df['geometry'].to_crs(4326).centroid
    north_eastern_mask = (city_centroids.x > centroid_x) & (city_centroids.y > centroid_y)
    return df[north_eastern_mask]

def south_eastern(df, centroid_x, centroid_y):
    city_centroids = df['geometry'].to_crs(4326).centroid
    south_eastern_mask = (city_centroids.x > centroid_x) & (city_centroids.y < centroid_y)
    return df[south_eastern_mask]

def north_western(df, centroid_x, centroid_y):
    city_centroids = df['geometry'].to_crs(4326).centroid
    north_western_mask = (city_centroids.x < centroid_x) & (city_centroids.y > centroid_y)
    return df[north_western_mask]

def south_western(df, centroid_x, centroid_y):
    city_centroids = df['geometry'].to_crs(4326).centroid
    south_western_mask = (city_centroids.x < centroid_x) & (city_centroids.y < centroid_y)
    return df[south_western_mask]

# %%
def urban_centers(df):
    return df[df['DEGURBA'] == 1]

def towns(df):
    return df[df['DEGURBA'] == 2]

def rural_area(df):
    return df[df['DEGURBA'] == 3]

# %%
for country, df in country_dfs.items():
    print(country)
    print(df.nlargest(50, ['a_tot'])[['bldgs_n_tot', 'bldgs_per_km2', 'a_tot', 'build_up_area']].quantile(0.25))
    # print(df[['a_3d', 'build_up_area_3d', 'a_tot']].mean())
# Out:
# netherlands
# bldgs_n_tot      3.279200e+04
# bldgs_per_km2    3.125520e+02
# a_tot            5.470344e+06
# build_up_area    5.355809e-02
# Name: 0.25, dtype: float64
# france
# bldgs_n_tot      4.697925e+04
# bldgs_per_km2    2.433429e+02
# a_tot            7.021310e+06
# build_up_area    3.496673e-02
# Name: 0.25, dtype: float64
# spain
# bldgs_n_tot      1.932050e+04
# bldgs_per_km2    1.081154e+02
# a_tot            6.324644e+06
# build_up_area    2.798800e-02
# Name: 0.25, dtype: float64

# %% [markdown]
# ### 3. Criteria for differentiating between rural and suburban areas

# %%
import webbrowser
import random

def filter_suburban_areas(settlements, urban_centers, verbose=False):
    urban_center_centroids = urban_centers['geometry'].to_crs(4326).centroid
    city_centroids = settlements['geometry'].to_crs(4326).centroid

    matrix = geometry.pairwise_distance_matrix(city_centroids, urban_center_centroids)
    matrix = matrix - city_radius(urban_centers)
    matrix = matrix - city_radius(settlements).T

    min_km_to_nearest_city = 10
    autonomous_settlements = [city_idx for city_idx, nearby_urban_centers in enumerate(matrix) if nearby_urban_centers.min() > min_km_to_nearest_city]

    if verbose:
        suburban_settlements = [(settlements.iloc[city_idx]['city'], urban_centers.iloc[nearby_urban_centers.argmin()]['city']) for city_idx, nearby_urban_centers in enumerate(matrix) if nearby_urban_centers.min() < min_km_to_nearest_city]
        print(f'The following suburban {len(suburban_settlements)} areas were identified and removed:', *suburban_settlements, sep='\n- ')

        for start, destination in random.choices(suburban_settlements, k=5):
            webbrowser.open(f'https://www.google.com/maps/dir/{start}/{destination}/')


    return settlements.iloc[autonomous_settlements]


def city_radius(df):
    # defined as shortest distance between a city's centroid and its gadm boundary in km
    return np.array([df['geometry'].boundary.to_crs(3035).distance(df['geometry'].to_crs(3035).centroid) / 1000])


# Exemplary filtering
# df = country_dfs['france']
# urban_regions = df[(df['bldgs_per_km2'] > 500) & (df['bldgs_n_tot'] > 10000)]
# rural_regions = df[(df['age_p'] > 0.3) & (df['bldgs_per_km2'].between(0, 200)) & (df['bldgs_n_tot'] < 10000)]

# filter_suburban_areas(rural_regions, urban_regions, verbose=True)
# filter_suburban_areas(towns(df), urban_regions, verbose=True)

# urban_regions[['city', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area']].sort_values('bldgs_n_tot', ascending=False)
# rural_regions[['city', 'bldgs_n_tot', 'bldgs_per_km2', 'build_up_area']].sort_values('bldgs_per_km2', ascending=False)

# %% [markdown]
# ### 4. Criteria for outlier removal

# %%
def inliers(df, low=0.1, high=0.8, iqr_tolerance=False):
    quantile_cols = ['age_p_1901_1950', 'age_p_1951_2000', 'age_p_2001_2022']
    quantiles = df[quantile_cols].quantile([low, high])
    quantiles.loc['IQR'] = quantiles.loc[high] - quantiles.loc[low]

    if iqr_tolerance:
        quantiles.loc[high] = quantiles.loc[high] + quantiles.loc['IQR']
        quantiles.loc[low] = quantiles.loc[low] - quantiles.loc['IQR']


    for col in quantile_cols:
        df = df[(df[col] > quantiles.loc[low, col]) & (df[col] < quantiles.loc[high, col])]

    return df

# %% [markdown]
# ### 5. Final selection of cities (with respective # of buildings with age attribute)

# %%
# Out:
# ['Borger-Odoorn',
#  'Weststellingwerf',
#  'Dinkelland',
#  'Het Bildt',
#  'Buren',
#  'Roggel en Neer',
#  'Drechterland',
#  'Veere',
#  'Goedereede',
#  'Hérisson',
#  'Huriel',
#  'Le Montet',
#  'Souvigny',
#  'Thonon-les-Bains-Ouest',
#  'Montigny-sur-Aube',
#  'Recey-sur-Ource',
#  'Marchaux',
#  'Saint-Hippolyte',
#  'Vercel-Villedieu-le-Camp',
#  'Adelans-et-le-Val-de-Bithaine',
#  'Champagney',
#  'Héricourt-Ouest',
#  'Villers-Farlay',
#  'Arinthod',
#  'Orgelet',
#  'Sellières',
#  'Château-Chinon (Ville)',
#  'Tannay',
#  'Pougues-les-Eaux',
#  'Chalon-sur-Saône-Sud',
#  "La Chapelle-d'Angillon",
#  'Lorris',
#  'Pithiviers',
#  'Estissac',
#  'Lusigny-sur-Barse',
#  'Wasselonne',
#  'Obernai',
#  'Altkirch',
#  'Hirsingue',
#  'Wintzenheim',
#  'Guebwiller',
#  'Ribeauvillé',
#  'Clefmont',
#  'Fayl-Billot',
#  'Saint-Dizier-Nord-Est',
#  'Longuyon',
#  'Toul-Nord',
#  'Château-Salins',
#  'Phalsbourg',
#  'Réchicourt-le-Château',
#  'Sarralbe',
#  'Metzervisse',
#  'Laon-Nord',
#  'Tergnier',
#  'Soissons-Nord',
#  'Cambrai-Ouest',
#  'Hazebrouck-Sud',
#  'Saint-Amand-les-Eaux-Rive droite',
#  'Attichy',
#  'Betz',
#  'Aubigny-en-Artois',
#  'Avesnes-le-Comte',
#  'Saint-Pol-sur-Ternoise',
#  'Auchel',
#  'Ham',
#  'Roisel',
#  'Mormant',
#  'Seyssel',
#  'Seyssel',
#  'Villars-les-Dombes',
#  'Cusset-Nord',
#  'Saint-Agrève',
#  'Pierrefort',
#  'Ruynes-en-Margeride',
#  'Romans-sur-Isère  1er Canton',
#  "Saint-Donat-sur-l'Herbasse",
#  'Saint-Vallier',
#  'Paulhaguet',
#  'Pradelles',
#  'Montfaucon-en-Velay',
#  'Retournac',
#  'Samoëns',
#  'Annemasse-Nord',
#  'Saint-Julien-en-Genevois',
#  'Chamrousse',
#  'Saint-Marcellin',
#  'Beaurepaire',
#  'Heyrieux',
#  'Saint-Just-Saint-Rambert',
#  'Ambert',
#  'Ardes',
#  'Aigueperse',
#  'Ennezat',
#  'Pionsat',
#  'Riom-Est',
#  "Saint-Gervais-d'Auvergne",
#  'Albertville-Nord',
#  'Saint-Genix-sur-Guiers',
#  'Lanslebourg-Mont-Cenis',
#  'Saint-Jean-de-Maurienne',
#  'Ginestas',
#  'Cassagnes-Bégonhès',
#  'Espalion',
#  'Le Vigan',
#  'Valleraugue',
#  'Saint-Mamert-du-Gard',
#  'Bédarieux',
#  'Béziers  2e  Canton',
#  'Servian',
#  'Castries',
#  'Anglès',
#  'Labruguière',
#  'Le Lauzet-Ubaye',
#  'Annot',
#  'Saint-André-les-Alpes',
#  'La Javie',
#  'Valensole',
#  'Manosque-Sud-Est',
#  'Reillanne',
#  'Levens',
#  'Menton-Est',
#  'Roquesteron',
#  'Orgon',
#  'Tarascon',
#  'Briançon-Nord',
#  'Guillestre',
#  "L'Argentière-la-Bessée",
#  'Le Monêtier-les-Bains',
#  'La Bâtie-Neuve',
#  'Grimaud',
#  "L'Isle-sur-la-Sorgue",
#  'Vaison-la-Romaine',
#  'Broons',
#  'Mûr-de-Bretagne',
#  'Plouagat',
#  'Moncontour',
#  'Paimpol',
#  'Quintin',
#  'Landerneau',
#  'Ploudalmézeau',
#  'Ploudiry',
#  'Plouigneau',
#  'Arzano',
#  'Fougères-Nord',
#  'La Guerche-de-Bretagne',
#  'Tinténiac',
#  'Belle-Île',
#  'Port-Louis',
#  'Le Faouët',
#  'Mauron',
#  'Ploërmel',
#  'Vannes-Ouest',
#  'Mainvilliers',
#  'Orgères-en-Beauce',
#  'Argenton-sur-Creuse',
#  'Éguzon-Chantôme',
#  'Herbault',
#  'Romorantin-Lanthenay-Sud',
#  'Formerie',
#  'Méru',
#  'Noailles',
#  'Crécy-en-Ponthieu',
#  'Picquigny',
#  'Guerville',
#  'Bretteville-sur-Laize',
#  'Creully',
#  'Falaise-Nord',
#  'Morteaux-Coulibœuf',
#  'Tilly-sur-Seulles',
#  'Aunay-sur-Odon',
#  'Vernon-Nord',
#  'Louviers-Sud',
#  'Val-de-Reuil',
#  'Ducey',
#  'Jullouville',
#  'Saint-Sauveur-le-Vicomte',
#  'Bréhal',
#  'Saint-Lô-Ouest',
#  'Tessy-sur-Vire',
#  'Carrouges',
#  'Le Mêle-sur-Sarthe',
#  'Argentan-Est',
#  'La Ferté-Frênel',
#  'Vimoutiers',
#  'Argueil',
#  'Cany-Barville',
#  'Fauville-en-Caux',
#  "Saint-Maixent-l'École  2e  Canton",
#  'Saint-Loup-Lamairé',
#  'Secondigny',
#  'Moisdon-la-Rivière',
#  'Rougé',
#  'Aigrefeuille-sur-Maine',
#  'Montfaucon-Montigné',
#  'Allonnes',
#  'Allonnes',
#  'Montsûrs',
#  'Saint-Berthevin',
#  'Ernée',
#  'Gorron',
#  'Loué',
#  'Fresnay-sur-Sarthe',
#  'Mamers',
#  'Chantonnay',
#  "L'Île-d'Yeu",
#  'Aigre',
#  'Confolens-Sud',
#  'Mirambeau',
#  'Saint-Genis-de-Saintonge',
#  'Ars-en-Ré',
#  "Le Château-d'Oléron",
#  'Matha',
#  'Meyssac',
#  'Bourganeuf',
#  'Bussière-Badil',
#  'Mareuil',
#  'Périgueux-Nord-Est',
#  'Saint-Pierre-de-Chignac',
#  'Vergt',
#  'Blaye',
#  'Podensac',
#  'Targon',
#  'Coutras',
#  'Amou',
#  'Tartas',
#  'Tartas-Est',
#  'Tartas-Ouest',
#  'Mont-de-Marsan-Sud',
#  'Saint-Sever',
#  'Villeneuve-de-Marsan',
#  'Agen-Nord',
#  'Fumel',
#  'La Bastide-Clairence',
#  'Ustaritz',
#  'Oloron-Sainte-Marie-Ouest',
#  'Arthez-de-Béarn',
#  'Lectoure',
#  'Riscle',
#  'Le Fousseret',
#  'Montesquieu-Volvestre',
#  'Aspet',
#  'Saint-Gaudens',
#  'Salies-du-Salat',
#  'Bagnères-de-Bigorre',
#  'Montcuq',
#  'Cajarc',
#  'Gourdon',
#  'Dourgne',
#  'Benasque',
#  'Capella',
#  'Villanova',
#  'Gistaín',
#  'Tella-Sin',
#  'Abiego',
#  'Colungo',
#  'Naval',
#  'Salas Altas',
#  'Santa María de Dulcis',
#  'Alcampell',
#  'Almunia de San Juan',
#  'Castelflorite',
#  'Albero Alto',
#  'Alerre',
#  'Igriés',
#  'Loporzano',
#  'Loscorrales',
#  'Lupiñén-Ortilla',
#  'Salillas',
#  'Aisa',
#  'Lledó',
#  'Allueva',
#  'Camarillas',
#  'Cucalón',
#  'Jarque de la Val',
#  'Lagueruela',
#  'Torrecilla del Rebollar',
#  'Vivel del Río Martín',
#  'Cañada de Benatanduz',
#  'Gúdar',
#  'Villarluengo',
#  'Monterde de Albarracín',
#  'Pozondón',
#  'Barrachina',
#  'Bueña',
#  'Burbáguena',
#  'Castejón de Tornos',
#  'Monreal del Campo',
#  'Navardún',
#  'Pradilla de Ebro',
#  'Santa Eulalia de Gállego',
#  'Sierra de Luna',
#  'Leciñena',
#  'Mediana de Aragón',
#  'Mozota',
#  'Aguilón',
#  'Lumpiaque',
#  'Plasencia de Jalón',
#  'Villafeliche',
#  'Villarroya del Campo',
#  'Alconchel de Ariza',
#  'Ateca',
#  'Brea de Aragón',
#  'Cimballa',
#  'Embid de Ariza',
#  'Illueca',
#  'Miedes de Aragón',
#  'Olvés',
#  'Velilla de Jiloca',
#  'Villarroya de la Sierra',
#  'Alberite de San Juan',
#  'Fréscano',
#  'San Martín de la Virgen de Moncayo',
#  'Talamantes',
#  'Alborge',
#  'Hazas de Cesto',
#  'Ribamontán al Monte',
#  'Riotuerto',
#  'Alcantud',
#  'Santa María del Val',
#  'Mazarete',
#  'Tierzo',
#  'Torrubia',
#  'Villel de Mesa',
#  'Gajanejos',
#  'Matillas',
#  'Muduex',
#  'Olmeda de Cobeta',
#  'San Andrés del Rey',
#  'Solanillos del Extremo',
#  'Alcocer',
#  'Auñón',
#  'Castilforte',
#  'Mantiel',
#  'Salmerón',
#  'Loranca de Tajuña',
#  'Mohernando',
#  'Valfermoso de Tajuña',
#  'Yunquera de Henares',
#  'Condemios de Arriba',
#  'Galve de Sorbe',
#  'Majaelrayo',
#  'Miedes de Atienza',
#  'Pinilla de Jadraque',
#  'Rebollosa de Jadraque',
#  'Tortuero',
#  'Valverde de los Arroyos',
#  'Castillejo de Mesleón',
#  'Grajera',
#  'Sequera de Fresno',
#  'Carrascosa de la Sierra',
#  'Fuentestrún',
#  'Suellacabras',
#  'Buberos',
#  'Candilichera',
#  'Castilruiz',
#  'Deza',
#  'Villaseca de Arciel',
#  'Bayubas de Arriba',
#  'Calatañazor',
#  'Golmayo',
#  'Rioseco de Soria',
#  'Adradas',
#  'Miño de Medinaceli',
#  'Villasayas',
#  'Fuentearmegil',
#  'Guils de Cerdanya',
#  'Llívia',
#  'Argelaguer',
#  'Castellfollit de la Roca',
#  'Tortellà',
#  'Juià',
#  'Sant Gregori',
#  'Viladasens',
#  'Vilademuls',
#  'Garriguella',
#  'Mollet de Peralada',
#  'Sant Climent Sescebes',
#  'Fontanilles',
#  'Serra de Daró',
#  'Ullastret',
#  'Verges',
#  'Canejan',
#  'Maials',
#  'Esterri de Cardós',
#  'Lladorre',
#  'Arsèguel',
#  'Cava',
#  'Abella de la Conca',
#  'Talarn',
#  'Lladurs',
#  'Llobera',
#  'Navès',
#  'Foradada',
#  'Os de Balaguer',
#  "Bellmunt d'Urgell",
#  'Sant Guim de la Plana',
#  'Puigverd de Lleida',
#  'Torrelameu',
#  'Savallà del Comtat',
#  'Montferri',
#  'Rodonyà',
#  "Vilanova d'Escornalbou",
#  'Poboleda',
#  'Xerta',
#  'Pira',
#  'Senan',
#  'Vallclara',
#  'Vilaverd',
#  'Cervera de Buitrago',
#  'Prádena del Rincón',
#  'Puentes Viejas',
#  'Torremocha de Jarama',
#  'Valdeavero',
#  'Valdetorres de Jarama',
#  'Tírig',
#  'Viniegra de Abajo',
#  'Badarán',
#  'Fonzaleche',
#  'Hormilleja',
#  'San Vicente de la Sonsierra',
#  'Santurde de Rioja',
#  'Tormantos',
#  'Torremontalbo',
#  'Treviana',
#  'Pazuengos',
#  'Hornillos de Cameros',
#  'Nieva de Cameros',
#  'Pradillo',
#  'Alcanadre',
#  'Las Peñas de Riglos',
#  'La Mata de los Olmos',
#  'Las Parras de Castellote',
#  'La Cuba',
#  'La Iglesuela del Cid',
#  'La Vilueña',
#  'La Almolda',
#  'El Pedregal',
#  'La Riba de Escalote',
#  'El Port de la Selva',
#  'Les Piles',
#  'El Catllar',
#  'La Riera de Gaià',
#  'Les Borges del Camp',
#  'La Febró',
#  'Los Santos de la Humosa',
#  'Isona i Conca Dellà (Cataluña)',
#  'Castril',
#  'Cortes de Baza',
#  'Albuñán',
#  'Beas de Guadix',
#  'Lugros',
#  'Polícar',
#  'Cogollos de la Vega',
#  'Lújar',
#  'Polopos',
#  'Cádiar',
#  'Cástaras',
#  'Montejícar',
#  'Morelábor',
#  'Villatorres',
#  'Orcera',
#  'Pegalajar',
#  'Aldeaquemada',
#  'Fuentes de Rubielos',
#  'Nogueruelas',
#  'Corbalán',
#  'Villar del Cobo',
#  'Alcubillas',
#  'Leganiel',
#  'Villanueva de Guadamejud',
#  'Abia de la Obispalía',
#  'Enguídanos',
#  'Fresneda de Altarejos',
#  'Palomera',
#  'Alcalá de la Vega',
#  'Moya',
#  'Santa Cruz de Moya',
#  'Talayuelas',
#  'Altarejos',
#  'Belmontejo',
#  'Castillo de Garcimuñoz',
#  'Huelves',
#  'Montalbanejo',
#  'San Lorenzo de la Parrilla',
#  'Tribaldos',
#  'Zafra de Záncara',
#  'Alarcón',
#  'Belmonte',
#  'Fuentelespino de Haro',
#  'Pozoamargo',
#  'Illana',
#  'Yebra',
#  'Villafranca de los Caballeros',
#  'Valdelaguna',
#  'Torralba del Pinar',
#  'Sot de Ferrer',
#  'Culla',
#  "Vall d'Alba",
#  'Segart',
#  'Bicorp',
#  'Vallada',
#  'Alborache',
#  'Llocnou de Sant Jeroni',
#  'Rótova',
#  'Gavarda',
#  'Chulilla',
#  'Bèlgida',
#  'Pinet',
#  'Zarra',
#  "La Torre d'En Besora",
#  'Sueras',
#  'Villalonga',
#  'Masalavés',
#  'Real de Montroi',
#  'La Yesa',
#  'Benisuera',
#  'El Palomar',
#  'Guadasequies',
#  'Las Valeras',
#  'Pozorrubio',
#  'Domeño (Comunidad Valenciana)',
#  'Pesquera',
#  'Villaescusa',
#  'Valdáliga',
#  'Cabezón de Liébana',
#  'Lamasón',
#  'Mazcuerras',
#  'Puente Viesgo',
#  'Miera',
#  'Arganza',
#  'Sancedo',
#  'Cuadros',
#  'Burón',
#  'Luyego',
#  'Palacios del Sil',
#  'Magaz de Cepeda',
#  'Santa Colomba de Somoza',
#  'Villamejil',
#  'Villarejo de Órbigo',
#  'Bercianos del Páramo',
#  'Laguna de Negrillos',
#  'Roperuelos del Páramo',
#  'Valdefuentes del Páramo',
#  'Valdevimbre',
#  'Destriana',
#  'Cubillas de los Oteros',
#  'Gordoncillo',
#  'Vega de Infanzones',
#  'Villaquejida',
#  'Castrotierra de Valmadrigal',
#  'Vallecillo',
#  'Lagartos',
#  'Ledigos',
#  'Pino del Río',
#  'Quintanilla de Onsoña',
#  'Valderrábano',
#  'Villarrabé',
#  'Autilla del Pino',
#  'Boadilla de Rioseco',
#  'Itero de la Vega',
#  'Marcilla de Campos',
#  'Mazariegos',
#  'Osorno la Mayor',
#  'Perales',
#  'Villamartín de Campos',
#  'Villaumbrales',
#  'Santibáñez de Ecla',
#  'Villaprovedo',
#  'Cervera de Pisuerga',
#  'Villalba de Guardo',
#  'Brañosera',
#  'Dueñas',
#  'Población de Cerrato',
#  'Tariego de Cerrato',
#  'Villaconancio',
#  'Villahán',
#  'Villodrigo',
#  'Aldeanueva de Figueroa',
#  'Parada de Arriba',
#  'Pelabravo',
#  'Alba de Tormes',
#  'Encinas de Arriba',
#  'Gajates',
#  'Peñarandilla',
#  'Aldehuela de Yeltes',
#  'Pelarrodríguez',
#  'San Pedro de Rozados',
#  'Mieza',
#  'Pereña de la Ribera',
#  'Saldeana',
#  'Aldearrodrigo',
#  'Palacios del Arzobispo',
#  'Tremedal de Tormes',
#  'Vega de Tirados',
#  'Aldeanueva de la Sierra',
#  'Garcibuey',
#  'Puebla de San Medel',
#  'Sorihuela',
#  'Alba de Yeltes',
#  'Aldea del Obispo',
#  'Herguijuela de Ciudad Rodrigo',
#  'Monsagro',
#  'Serradilla del Arroyo',
#  'Zamarra',
#  'Puente del Congosto',
#  'Aldeanueva de la Serrezuela',
#  'Castro de Fuentidueña',
#  'Condado de Castilnovo',
#  'Honrubia de la Cuesta',
#  'Navalilla',
#  'San Miguel de Bernuy',
#  'Codorniz',
#  'Donhierro',
#  'Marazoleja',
#  'Martín Muñoz de la Dehesa',
#  'Mozoncillo',
#  'Navas de Oro',
#  'Ortigosa de Pestaño',
#  'Veganzones',
#  'Rebollo',
#  'Santiuste de Pedraza',
#  'Valseca',
#  'Cabreros del Monte',
#  'Urones de Castroponce',
#  'Urueña',
#  'Villacarralón',
#  'Villacid de Campos',
#  'Villafrechós',
#  'Villalba de la Loma',
#  'Villanueva de los Caballeros',
#  'Castromonte',
#  'Tiedra',
#  'Cogeces de Íscar',
#  'Quintanilla de Onésimo',
#  'Ramiro',
#  'San Miguel del Arroyo',
#  'Castronuño',
#  'Salvador de Zapardiel',
#  'San Pablo de la Moraleja',
#  'Torrecilla de la Orden',
#  'Friera de Valverde',
#  'Manganeses de la Polvorosa',
#  'Matilla de Arzón',
#  'Morales de Valverde',
#  'Pueblica de Valverde',
#  'Santovenia',
#  'Lubián',
#  'Peque',
#  'Rionegro del Puente',
#  'Rosinos de la Requejada',
#  'Riofrío de Aliste',
#  'Samir de los Caños',
#  'Viñas',
#  'Abezames',
#  'Pinilla de Toro',
#  'Villalube',
#  'Fermoselle',
#  'Fresno de Sayago',
#  'Moral de Sayago',
#  'Cuelgamures',
#  'Sanzoles',
#  'Boqueixón',
#  'Camariñas',
#  'Muros',
#  'Muxía',
#  'Coristanco',
#  'Monfero',
#  'Taboada',
#  'Portomarín',
#  'Pol',
#  'Mondoñedo',
#  'San Amaro',
#  'Xunqueira de Ambía',
#  'Chandrexa de Queixa',
#  'Pazos de Borbén',
#  'Candamo',
#  'Pesoz',
#  'Vegadeo',
#  'Sobrescobio',
#  'Amieva',
#  'Llanes',
#  'Parres',
#  'Peñamellera Alta',
#  'Quirós',
#  'A Capela',
#  'O Saviñao',
#  'A Merca',
#  'A Rúa',
#  'O Rosal',
#  'A Cañiza',
#  'El Burgo Ranero',
#  'El Arco',
#  'La Parrilla',
#  'Retortillo (Castilla y León)',
#  'Grazalema',
#  'Moriles',
#  'Conquista',
#  'Fuente Obejuna',
#  'Espiel',
#  'Villaviciosa de Córdoba',
#  'Palenciana',
#  'Luque',
#  'Santa Cruz del Comercio',
#  'Zafarraya',
#  'Otívar',
#  'Cortelazor',
#  'Cumbres de San Bartolomé',
#  'Cumbres Mayores',
#  'Galaroza',
#  'Santa Ana la Real',
#  'Alosno',
#  'Calañas',
#  'Niebla',
#  'Cazalilla',
#  'Baños de la Encina',
#  'Frailes',
#  'Alcaucín',
#  'Cútar',
#  'Salares',
#  'Villanueva de Algaidas',
#  'Benadalid',
#  'Benalauría',
#  'Villamanrique de la Condesa',
#  'Aguadulce',
#  'Alcolea de Calatrava',
#  'Corral de Calatrava',
#  'Navalpino',
#  'Brazatortas',
#  'Hinojosas de Calatrava',
#  'Manzaneque',
#  'Marjaliza',
#  'Menasalbas',
#  'Aldea en Cabo',
#  'Burujón',
#  'Paredes de Escalona',
#  'Rielves',
#  'Torralba de Oropesa',
#  'Cobeja',
#  'Layos',
#  'Yunclillos',
#  'Puerto de Béjar',
#  'Robleda',
#  'Segura de Toro',
#  'Abertura',
#  'Alcollarín',
#  'Cañamero',
#  'Oliva de Plasencia',
#  'Pasarón de la Vera',
#  'Piornal',
#  'Santa Cruz de Paniagua',
#  'Valverde del Fresno',
#  'Villa del Campo',
#  'Monroy',
#  'Torreorgaz',
#  'Valdefuentes',
#  'Alcántara',
#  'Millanes',
#  'Valdelacasa de Tajo',
#  'Villar del Pedroso',
#  'Hermigua',
#  'La Granjuela',
#  'El Guijo',
#  'El Campillo',
#  'Los Molares',
#  'El Saucejo',
#  'La Torre de Esteban Hambrán',
#  'La Iglesuela',
#  'La Pueblanueva',
#  'Los Navalucillos']

# %%
for country, df in country_dfs.items():
    print(f'{len(df) - len(df.dropna(subset=["DEGURBA"]))} unknown DEGURBA types for {country}.')
    df['DEGURBA'].fillna('unknown', inplace=True)
# Out:
# 0 unknown DEGURBA types for netherlands.
# 0 unknown DEGURBA types for france.
# 0 unknown DEGURBA types for spain.

# %%
with open(os.path.join('..', 'metadata', 'hyperparameter-tuning-cities.json'), 'r', encoding='utf-8') as f:
    selected_cities = json.load(f)
utils.flatten([region_cities for type_cities in selected_cities['netherlands'].values() for region_cities in type_cities.values()])
# selected_cities['netherlands'].values()
# Out:
# ['Apeldoorn',
#  'Bathmen',
#  'Brunssum',
#  'Veenendaal',
#  'Amsterdam',
#  'Bloemendaal',
#  'Heemstede',
#  'IJsselstein',
#  'Vlissingen',
#  'Alphen aan den Rijn',
#  'Binnenmaas',
#  'Dronten',
#  'Tytsjerksteradiel',
#  'Voorst',
#  'Oldenzaal',
#  'Staphorst',
#  'Bunschoten',
#  'Beuningen',
#  'Renkum',
#  'Deurne',
#  'Valkenswaard',
#  'Dinxperlo',
#  'Groesbeek',
#  'Rijnwaarden',
#  'Nuth',
#  'Maasdonk',
#  'Sint-Oedenrode',
#  'Blaricum',
#  'Uithoorn',
#  'De Ronde Venen',
#  'Jacobswoude',
#  'Zijpe',
#  'Drimmelen',
#  'Geertruidenberg',
#  'Woerden',
#  'Kapelle',
#  'Brielle',
#  'Vianen',
#  'Liesveld',
#  'Borger-Odoorn',
#  'Weststellingwerf',
#  'Dinkelland',
#  'Het Bildt',
#  'Buren',
#  'Roggel en Neer',
#  'Drechterland',
#  'Veere',
#  'Goedereede']

# %%
import collections
import json
import pickle

selected_cities = collections.defaultdict(lambda: collections.defaultdict(dict))

regions = {'north-east': north_eastern, 'south-east': south_eastern, 'north-west': north_western, 'south-west': south_western}
deburba_types = {1: 'urban', 2: 'town', 3: 'rural', 'unknown': 'unknown'}

for country, df in country_dfs.items():
    # df = df[df['age_p'] > 0.3]

    for type, df_type in df.groupby('DEGURBA'):

        for region, filter in regions.items():
            df_region = filter(df_type, *centroid_coordinates[country])

            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # df_region_sample = utils.sample_cities_with_distributional_constraint(df_region, frac=0.2, attr='a_3d', min_samples_per_group=5)
                if len(df_region) > 0:
                    df_region_sample = utils.sample_cities(df_region, frac=0.1)
                    selected_cities[country][type][region] = list(df_region_sample['city'].values)

                    print(f'{country} - {deburba_types[type]} area - {region} region: {(len(df_region_sample) / len(df)) * 100:.1f}% (#cities {len(df_region_sample)}) (#buildings {str(int((df_region_sample["bldgs_n_tot"] * df_region_sample["age_p"]).sum()))[:-3]}k)')


with open(os.path.join('..', 'metadata', f'selected-cities.json'), 'w', encoding='utf-8') as f:
    json.dump(selected_cities, f, ensure_ascii=False, indent=4)

with open(os.path.join('..', 'metadata', f'selected-cities.pkl'), 'wb') as f:
    selected_cities_flattened = utils.flatten([region_cities for country_cities in selected_cities.values() for type_cities in country_cities.values() for region_cities in type_cities.values()])
    print(f'Overall selected {len(selected_cities_flattened)} cities')
    pickle.dump(selected_cities_flattened, f)

    # print(f'{country}: share of region {region}: {(len(filter(df)) / len(df)):.3f}')

# n_type = {'urban': 3, 'town': 30, 'rural': 30}
# settlement_types = {'urban': urban_centers, 'town': towns, 'rural': rural_area}

# for country, df in country_dfs.items():
#     for type in settlement_types:
#         df_type = settlement_types[type](df)

#         # special cases
#         if country == 'france' and type == 'rural':
#             # gadm level 4 yields partially fragmented cities;
#             # therefore, rural settlements are checked to not be a suburban area / have a minimum distance to nearby urban regions
#             urban_regions = df[(df['bldgs_per_km2'] > 500) & (df['bldgs_n_tot'] > 10000)]
#             df_type = filter_suburban_areas(df_type, urban_regions)

#         # if type != 'urban':
#         #     df_type = inliers(df_type, low=0.1, high=0.9)

#         for region in regions:
#             df_cat = regions[region](df_type, *centroid_coordinates[country])

#             # n = int(len(df_cat) / len(regions.keys()))
#             # if len(df_cat) > 0:
#             #     df_cat = df_cat.sample(n=min(n_type[type], len(df_cat)), weights='age_p', random_state=dataset.GLOBAL_REPRODUCIBILITY_SEED)

#             print(f'{country}: share of {type} areas in region {region}: {(len(df_cat) / len(df)) * 100:.1f}% (#{type} {len(df_cat)}) (#buildings {str(int((df_cat["bldgs_n_tot"] * df_cat["age_p"]).sum()))[:-3]}k)')
#             selected_cities[type][region] = list(df_cat['city'].values)


#     with open(os.path.join('..', 'data', f'{country}-selected-cities-new.json'), 'w', encoding='utf-8') as f:
#         json.dump(selected_cities, f, ensure_ascii=False, indent=4)
# Out:
# netherlands - urban area - north-east region: 0.4% (#cities 2) (#buildings 108k)
# netherlands - urban area - south-east region: 0.4% (#cities 2) (#buildings 44k)
# netherlands - urban area - north-west region: 0.6% (#cities 3) (#buildings 195k)
# netherlands - urban area - south-west region: 0.8% (#cities 4) (#buildings 93k)
# netherlands - town area - north-east region: 1.2% (#cities 6) (#buildings 110k)
# netherlands - town area - south-east region: 2.0% (#cities 10) (#buildings 141k)
# netherlands - town area - north-west region: 1.0% (#cities 5) (#buildings 58k)
# netherlands - town area - south-west region: 1.4% (#cities 7) (#buildings 105k)
# netherlands - rural area - north-east region: 0.8% (#cities 4) (#buildings 72k)
# netherlands - rural area - south-east region: 0.4% (#cities 2) (#buildings 24k)
# netherlands - rural area - north-west region: 0.2% (#cities 1) (#buildings 6k)
# netherlands - rural area - south-west region: 0.4% (#cities 2) (#buildings 33k)
# france - urban area - north-east region: 0.2% (#cities 7) (#buildings 126k)
# france - urban area - south-east region: 0.2% (#cities 7) (#buildings 52k)
# france - urban area - north-west region: 0.2% (#cities 6) (#buildings 93k)
# france - urban area - south-west region: 0.1% (#cities 2) (#buildings 21k)
# france - town area - north-east region: 0.4% (#cities 16) (#buildings 113k)
# france - town area - south-east region: 0.4% (#cities 15) (#buildings 109k)
# france - town area - north-west region: 0.3% (#cities 10) (#buildings 80k)
# france - town area - south-west region: 0.2% (#cities 6) (#buildings 65k)
# france - rural area - north-east region: 2.0% (#cities 73) (#buildings 370k)
# france - rural area - south-east region: 1.9% (#cities 69) (#buildings 295k)
# france - rural area - north-west region: 2.0% (#cities 76) (#buildings 454k)
# france - rural area - south-west region: 1.4% (#cities 53) (#buildings 269k)
# france - unknown area - north-east region: 0.7% (#cities 25) (#buildings 83k)
# france - unknown area - north-west region: 0.2% (#cities 7) (#buildings 45k)
# france - unknown area - south-west region: 0.1% (#cities 3) (#buildings 8k)
# spain - urban area - north-east region: 0.0% (#cities 4) (#buildings k)
# spain - urban area - south-east region: 0.1% (#cities 6) (#buildings 29k)
# spain - urban area - north-west region: 0.0% (#cities 2) (#buildings 40k)
# spain - urban area - south-west region: 0.1% (#cities 5) (#buildings 44k)
# spain - town area - north-east region: 0.3% (#cities 24) (#buildings 66k)
# spain - town area - south-east region: 0.3% (#cities 22) (#buildings 158k)
# spain - town area - north-west region: 0.2% (#cities 15) (#buildings 101k)
# spain - town area - south-west region: 0.3% (#cities 26) (#buildings 154k)
# spain - rural area - north-east region: 2.9% (#cities 241) (#buildings 134k)
# spain - rural area - south-east region: 0.9% (#cities 75) (#buildings 79k)
# spain - rural area - north-west region: 2.1% (#cities 174) (#buildings 230k)
# spain - rural area - south-west region: 0.9% (#cities 75) (#buildings 133k)
# spain - unknown area - north-east region: 0.8% (#cities 64) (#buildings 124k)
# spain - unknown area - south-east region: 0.5% (#cities 40) (#buildings 170k)
# spain - unknown area - north-west region: 0.4% (#cities 34) (#buildings 37k)
# spain - unknown area - south-west region: 0.3% (#cities 23) (#buildings 75k)
# Overall selected 1253 cities

# %%
country_dfs['france']['age_p'].hist(bins=7)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### X. Deprecated approaches

# %% [markdown]
# #### Custom urban typology classifcation

# %%
# Netherlands
# def urban_centers(df):
#     return df[(df['age_p'] > 0.3) & (df['bldgs_per_km2'] > 500) & (df['bldgs_n_tot'] > 75000)]

# def towns(df):
#     return df[(df['age_p'] > 0.3) & df['bldgs_per_km2'].between(200, 500) & df['bldgs_n_tot'].between(10000, 50000)]

# def rural_area(df):
#     return df[(df['age_p'] > 0.3) & (df['bldgs_per_km2'].between(0, 200)) & (df['bldgs_n_tot'] < 10000)]

# France
# def urban_centers(df):
#     return df[(df['age_p'] > 0.3) & (df['bldgs_per_km2'] > 1000) & (df['build_up_area'] > 0.1) & (df['bldgs_n_tot'] > 50000)]

# def towns(df):
#     return df[(df['age_p'] > 0.3) & df['bldgs_per_km2'].between(100, 500) & df['bldgs_n_tot'].between(20000, 50000)]

# def rural_area(df):
#     return df[(df['age_p'] > 0.3) & (df['bldgs_per_km2'].between(0, 50)) & (df['bldgs_n_tot'] < 10000)]


# All countries
# def urban_centers(df):
#     return df[(df['age_p'] > 0.3) & (df['height_mean'] > 4) & (df['a_tot'] > 5000000)]
#     # return df[(df['age_p'] > 0.3) & (df['bldgs_per_km2'] > 500) & (df['bldgs_n_tot'] > 50000)]

# def towns(df):
#     return df[(df['age_p'] > 0.3) & df['bldgs_per_km2'].between(200, 500) & df['bldgs_n_tot'].between(10000, 50000)]

# def rural_area(df):
#     return df[(df['age_p'] > 0.3) & (df['bldgs_per_km2'].between(0, 200)) & (df['bldgs_n_tot'] < 10000)]

# def rural_area_france(df):
#     rural_regions = df[(df['age_p'] > 0.3) & (df['bldgs_per_km2'].between(0, 200)) & (df['bldgs_n_tot'] < 10000)]
#     urban_regions = df[(df['bldgs_per_km2'] > 500) & (df['bldgs_n_tot'] > 10000)]
#     return filter_suburban_areas(rural_regions, urban_regions)

def largest_cities(df):
    c1 = df.nlargest(50, ['bldgs_n_tot'])['city']
    c2 = df.nlargest(50, ['a_tot'])['city']
    # c3 = df.nlargest(50, ['build_up_area'])['city']
    cities = set(c1).intersection(c2)
    return  df[df['city'].isin(cities) & (df['age_p'] > 0.3)]

def relative_urban_centers(df):
    quantiles = df.nlargest(50, ['a_tot'])[['bldgs_n_tot', 'bldgs_per_km2', 'a_tot', 'build_up_area']].quantile(0.25)
    return df[
        (df['age_p'] > 0.3) &
        (df['bldgs_n_tot'] > quantiles['bldgs_n_tot']) &
        # (df['bldgs_per_km2'] > quantiles['bldgs_per_km2']) &
        (df['a_tot'] > quantiles['a_tot'])
        ]

def urban_centers(df):
    return df[(df['age_p'] > 0.3) & (df['a_3d'] > 40000000) & (df['build_up_area_3d'] > 0.3)].sort_values(by='a_3d', ascending=False)

def rural_area(df):
    return df[(df['age_p'] > 0.3) & (df['a_3d'] < 5000000) | (df['build_up_area_3d'] < 0.03)].sort_values(by='a_3d', ascending=False)

def towns(df):
    return df.drop(list(urban_centers(df).index) + list(rural_area(df).index))

# %% [markdown]
# #### Regional classification based on K-means clustering

# %%
from sklearn.cluster import KMeans
import numpy as np
import warnings

warnings.filterwarnings('ignore', message='Explicit initial center position passed')


def regional_clustering(df):
    city_centroids = df['geometry'].to_crs(4326).centroid
    df['lat'] = city_centroids.y
    df['lon'] = city_centroids.x

    nswe_inital_clusters = np.array([[52.2451, 4.8433], [52.63445462289726, 6.336618136624664], [51.5842, 4.1645], [51.4580, 5.8240]])
    kmeans = KMeans(n_clusters=4, random_state=0, init=nswe_inital_clusters)
    kmeans.fit(df[['lat', 'lon']])

    kmeans.cluster_centers_
    # city_region = dict(zip(df['city'], kmeans.labels_))
    return kmeans.labels_


def north_eastern(df):
    labels = regional_clustering(df)
    return df[labels == 1]

def south_eastern(df):
    labels = regional_clustering(df)
    return df[labels == 3]

def north_western(df):
    labels = regional_clustering(df)
    return df[labels == 0]

def south_western(df):
    labels = regional_clustering(df)
    return df[labels == 2]

# %%
len(set(country_dfs['spain'].sort_values(by='bldgs_n_tot', ascending=False).city.unique()[:50]) - set(pd.read_csv(os.path.join('/Users/D062794/Downloads', 'csvData.csv')).name.unique()))
country_dfs['spain'].sort_values(by='bldgs_n_tot', ascending=False).city.unique()[:50]

'Badajoz' in pd.read_csv(os.path.join('/Users/D062794/Downloads', 'csvData.csv')).name.unique()
# Out:
# False

# %% [markdown]
# #### Alterative approaches to GADM LAU alignment

# %%
# alternative straight-forward approach based on name merging
lau_es = lau_eu[lau_eu['CNTR_CODE'] == 'ES']
gadm_spain.merge(lau_es[['LAU_ID', 'LAU_NAME']], left_on='NAME_4', right_on='LAU_NAME', how='inner')

# %%
# alternative approach
# first match based on name and sjoin_nearest only ambiguous regions (to reduce computation complexity of sjoining all regions)

# drop all duplicates from both dfs and align them later with geopandas.sjoin_nearest
lau_fr = lau_eu[lau_eu['CNTR_CODE'] == 'FR']
lau_fr_distinct = lau_fr.drop_duplicates(subset='LAU_NAME', keep=False)
gadm_5_france_distinct = gadm_5_france.drop_duplicates(subset='NAME_5', keep=False)

gadm_france_lau = gadm_5_france_distinct.merge(lau_fr_distinct[['LAU_ID', 'LAU_NAME']], left_on='NAME_5', right_on='LAU_NAME', how='left')

lau_fr_ambiguous = lau_fr[~lau_fr['LAU_ID'].isin(gadm_france_lau['LAU_ID'])]
gadm_5_france_ambiguous = gadm_5_france.drop(gadm_5_france_distinct.index)

gadm_5_france_ambiguous_joined = gpd.sjoin_nearest(gadm_5_france_ambiguous.to_crs(3035), lau_fr_ambiguous[['LAU_ID', 'LAU_NAME', 'geometry']], how='left', max_distance=10000, distance_col='distance')
# https://stackoverflow.com/questions/71434825/attributeerror-module-geopandas-has-no-attribute-sjoin-nearest
# gadm_france_lau[gadm_france_lau.duplicated('GID_5')]
# gadm_france_lau[gadm_france_lau['GID_5'] == 'FRA.1.1.1.2.6_1']

# %%
# gadm_5_france[~gadm_5_france['GID_5'].isin(gadm_5_france_lau['GID_5'].unique())]
# _, ax = plt.subplots(1, 1)
# gadm_5_france_lau_distinct[gadm_5_france_lau_distinct['GID_5'].duplicated(keep=False)]
# dup = gadm_5_france_lau_distinct[gadm_5_france_lau_distinct['LAU_NAME'] == 'Seyssel']
# dup.plot(column='GID_5', ax=ax)
# gpd.GeoDataFrame(dup, geometry=dup['geometry_lau'], crs=3035).plot(ax=ax, color='red', hatch="//", alpha=0.1)

len(gadm_5_france) == len(gadm_5_france_lau)
# Out:
# True
